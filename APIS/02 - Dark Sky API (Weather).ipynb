# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests
from datetime import datetime

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
#one time make a .env
# !touch .env

# %%
API_KEY = os.getenv("DARKSKY_API_KEY")

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
#44.9537° N, 93.0900° W
url=f'https://api.darksky.net/forecast/{API_KEY}/44.9537,-93.0900'

# %%
data = requests.get(url).json()

# %%
data['currently']
# Out:
# {'time': 1560183433,
#  'summary': 'Clear',
#  'icon': 'clear-day',
#  'nearestStormDistance': 218,
#  'nearestStormBearing': 7,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 72.48,
#  'apparentTemperature': 72.48,
#  'dewPoint': 42.43,
#  'humidity': 0.34,
#  'pressure': 1021.77,
#  'windSpeed': 8.44,
#  'windGust': 9.62,
#  'windBearing': 303,
#  'cloudCover': 0,
#  'uvIndex': 6,
#  'visibility': 10,
#  'ozone': 368.92}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
#current wind speed
data['currently']['windSpeed']
# Out:
# 8.44

# %%
data['currently']['temperature']-data['currently']['apparentTemperature']
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
daily_forecast=data['daily']

# %%
daily_data=daily_forecast['data'][0]

# %%
daily_data['moonPhase']
# Out:
# 0.27

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
daily_data['temperatureHigh']-daily_data['temperatureLow']
# Out:
# 20.990000000000002

# %%
daily_forecast
# Out:
# {'summary': 'Light rain tomorrow and Wednesday, with high temperatures bottoming out at 66°F on Wednesday.',
#  'icon': 'rain',
#  'data': [{'time': 1560142800,
#    'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0005,
#    'precipIntensityMax': 0.0022,
#    'precipIntensityMaxTime': 1560204000,
#    'precipProbability': 0.08,
#    'precipType': 'rain',
#    'temperatureHigh': 76.64,
#    'temperatureHighTime': 1560196800,
#    'temperatureLow': 55.65,
#    'temperatureLowTime': 1560247200,
#    'apparentTemperatureHigh': 76.64,
#    'apparentTemperatureHighTime': 1560196800,
#    'apparentTemperatureLow': 55.65,
#    'apparentTemperatureLowTime': 1560247200,
#    'dewPoint': 44.63,
#    'humidity': 0.49,
#    'pressure': 1020.91,
#    'windSpeed': 6.57,
#    'windGust': 23.24,
#    'windGustTime': 1560200400,
#    'windBearing': 300,
#    'cloudCover': 0.08,
#    'uvIndex': 8,
#    'uvIndexTime': 1560189600,
#    'visibility': 10,
#    'ozone': 367.41,
#    'temperatureMin': 53.61,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 76.64,
#    'temperatureMaxTime': 1560196800,
#    'apparentTemperatureMin': 53.61,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 76.64,
#    'apparentTemperatureMaxTime': 1560196800},
#   {'time': 1560229200,
#    'summary': 'Light rain starting in the evening.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0107,
#    'precipIntensityMax': 0.0351,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.9,
#    'precipType': 'rain',
#    'temperatureHigh': 70.45,
#    'temperatureHighTime': 1560272400,
#    'temperatureLow': 53.36,
#    'temperatureLowTime': 1560340800,
#    'apparentTemperatureHigh': 70.45,
#    'apparentTemperatureHighTime': 1560272400,
#    'apparentTemperatureLow': 53.36,
#    'apparentTemperatureLowTime': 1560340800,
#    'dewPoint': 49.81,
#    'humidity': 0.66,
#    'pressure': 1018.1,
#    'windSpeed': 4.61,
#    'windGust': 18.37,
#    'windGustTime': 1560308400,
#    'windBearing': 191,
#    'cloudCover': 0.65,
#    'uvIndex': 4,
#    'uvIndexTime': 1560268800,
#    'visibility': 9.96,
#    'ozone': 365.77,
#    'temperatureMin': 55.65,
#    'temperatureMinTime': 1560247200,
#    'temperatureMax': 70.45,
#    'temperatureMaxTime': 1560272400,
#    'apparentTemperatureMin': 55.65,
#    'apparentTemperatureMinTime': 1560247200,
#    'apparentTemperatureMax': 70.45,
#    'apparentTemperatureMaxTime': 1560272400},
#   {'time': 1560315600,
#    'summary': 'Mostly cloudy until evening and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0056,
#    'precipIntensityMax': 0.0217,
#    'precipIntensityMaxTime': 1560315600,
#    'precipProbability': 0.85,
#    'precipType': 'rain',
#    'temperatureHigh': 65.82,
#    'temperatureHighTime': 1560380400,
#    'temperatureLow': 47.39,
#    'temperatureLowTime': 1560420000,
#    'apparentTemperatureHigh': 65.82,
#    'apparentTemperatureHighTime': 1560380400,
#    'apparentTemperatureLow': 44.24,
#    'apparentTemperatureLowTime': 1560420000,
#    'dewPoint': 48.44,
#    'humidity': 0.7,
#    'pressure': 1012.53,
#    'windSpeed': 7.96,
#    'windGust': 24.99,
#    'windGustTime': 1560351600,
#    'windBearing': 349,
#    'cloudCover': 0.68,
#    'uvIndex': 5,
#    'uvIndexTime': 1560362400,
#    'visibility': 9.81,
#    'ozone': 381.77,
#    'temperatureMin': 53.36,
#    'temperatureMinTime': 1560340800,
#    'temperatureMax': 65.82,
#    'temperatureMaxTime': 1560380400,
#    'apparentTemperatureMin': 53.36,
#    'apparentTemperatureMinTime': 1560340800,
#    'apparentTemperatureMax': 65.82,
#    'apparentTemperatureMaxTime': 1560380400},
#   {'time': 1560402000,
#    'summary': 'Partly cloudy in the evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0003,
#    'precipIntensityMax': 0.0024,
#    'precipIntensityMaxTime': 1560459600,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperatureHigh': 70.72,
#    'temperatureHighTime': 1560470400,
#    'temperatureLow': 51.43,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 70.72,
#    'apparentTemperatureHighTime': 1560470400,
#    'apparentTemperatureLow': 51.43,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 40.9,
#    'humidity': 0.5,
#    'pressure': 1013.74,
#    'windSpeed': 7.36,
#    'windGust': 17.66,
#    'windGustTime': 1560459600,
#    'windBearing': 291,
#    'cloudCover': 0.06,
#    'uvIndex': 7,
#    'uvIndexTime': 1560445200,
#    'visibility': 10,
#    'ozone': 386.61,
#    'temperatureMin': 47.39,
#    'temperatureMinTime': 1560420000,
#    'temperatureMax': 70.72,
#    'temperatureMaxTime': 1560470400,
#    'apparentTemperatureMin': 44.24,
#    'apparentTemperatureMinTime': 1560420000,
#    'apparentTemperatureMax': 70.72,
#    'apparentTemperatureMaxTime': 1560470400},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0011,
#    'precipIntensityMax': 0.0044,
#    'precipIntensityMaxTime': 1560560400,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 74.61,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 52.81,
#    'temperatureLowTime': 1560596400,
#    'apparentTemperatureHigh': 74.61,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 52.81,
#    'apparentTemperatureLowTime': 1560596400,
#    'dewPoint': 46.2,
#    'humidity': 0.54,
#    'pressure': 1011.72,
#    'windSpeed': 2.61,
#    'windGust': 18.78,
#    'windGustTime': 1560571200,
#    'windBearing': 156,
#    'cloudCover': 0.3,
#    'uvIndex': 6,
#    'uvIndexTime': 1560535200,
#    'visibility': 10,
#    'ozone': 351.18,
#    'temperatureMin': 51.43,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 74.61,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 51.43,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 74.61,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0043,
#    'precipIntensityMaxTime': 1560621600,
#    'precipProbability': 0.46,
#    'precipType': 'rain',
#    'temperatureHigh': 72.98,
#    'temperatureHighTime': 1560636000,
#    'temperatureLow': 60.33,
#    'temperatureLowTime': 1560675600,
#    'apparentTemperatureHigh': 72.98,
#    'apparentTemperatureHighTime': 1560636000,
#    'apparentTemperatureLow': 60.33,
#    'apparentTemperatureLowTime': 1560675600,
#    'dewPoint': 51.32,
#    'humidity': 0.65,
#    'pressure': 1012.13,
#    'windSpeed': 7.11,
#    'windGust': 19.76,
#    'windGustTime': 1560607200,
#    'windBearing': 110,
#    'cloudCover': 0.63,
#    'uvIndex': 4,
#    'uvIndexTime': 1560614400,
#    'visibility': 10,
#    'ozone': 333.71,
#    'temperatureMin': 52.81,
#    'temperatureMinTime': 1560596400,
#    'temperatureMax': 72.98,
#    'temperatureMaxTime': 1560636000,
#    'apparentTemperatureMin': 52.81,
#    'apparentTemperatureMinTime': 1560596400,
#    'apparentTemperatureMax': 72.98,
#    'apparentTemperatureMaxTime': 1560636000},
#   {'time': 1560661200,
#    'summary': 'Mostly cloudy until afternoon.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560680796,
#    'sunsetTime': 1560736939,
#    'moonPhase': 0.48,
#    'precipIntensity': 0.0007,
#    'precipIntensityMax': 0.0019,
#    'precipIntensityMaxTime': 1560708000,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 75.82,
#    'temperatureHighTime': 1560722400,
#    'temperatureLow': 60.51,
#    'temperatureLowTime': 1560765600,
#    'apparentTemperatureHigh': 75.82,
#    'apparentTemperatureHighTime': 1560722400,
#    'apparentTemperatureLow': 60.51,
#    'apparentTemperatureLowTime': 1560765600,
#    'dewPoint': 54.85,
#    'humidity': 0.65,
#    'pressure': 1012.67,
#    'windSpeed': 3.61,
#    'windGust': 15.99,
#    'windGustTime': 1560722400,
#    'windBearing': 202,
#    'cloudCover': 0.37,
#    'uvIndex': 6,
#    'uvIndexTime': 1560715200,
#    'visibility': 10,
#    'ozone': 339.34,
#    'temperatureMin': 60.33,
#    'temperatureMinTime': 1560675600,
#    'temperatureMax': 75.82,
#    'temperatureMaxTime': 1560722400,
#    'apparentTemperatureMin': 60.33,
#    'apparentTemperatureMinTime': 1560675600,
#    'apparentTemperatureMax': 75.82,
#    'apparentTemperatureMaxTime': 1560722400},
#   {'time': 1560747600,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560767199,
#    'sunsetTime': 1560823361,
#    'moonPhase': 0.52,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0322,
#    'precipIntensityMaxTime': 1560772800,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 79.78,
#    'temperatureHighTime': 1560808800,
#    'temperatureLow': 62.22,
#    'temperatureLowTime': 1560852000,
#    'apparentTemperatureHigh': 79.78,
#    'apparentTemperatureHighTime': 1560808800,
#    'apparentTemperatureLow': 62.22,
#    'apparentTemperatureLowTime': 1560852000,
#    'dewPoint': 54.88,
#    'humidity': 0.6,
#    'pressure': 1012.8,
#    'windSpeed': 5.74,
#    'windGust': 9.53,
#    'windGustTime': 1560751200,
#    'windBearing': 267,
#    'cloudCover': 0.02,
#    'uvIndex': 9,
#    'uvIndexTime': 1560794400,
#    'visibility': 10,
#    'ozone': 339.67,
#    'temperatureMin': 60.51,
#    'temperatureMinTime': 1560765600,
#    'temperatureMax': 79.78,
#    'temperatureMaxTime': 1560808800,
#    'apparentTemperatureMin': 60.51,
#    'apparentTemperatureMinTime': 1560765600,
#    'apparentTemperatureMax': 79.78,
#    'apparentTemperatureMaxTime': 1560808800}]}

# %%
daily_stuff =[daily_forecast['data'] for daily in daily_forecast ]

# %%
daily_stuff
# Out:
# [[{'time': 1560142800,
#    'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0005,
#    'precipIntensityMax': 0.0022,
#    'precipIntensityMaxTime': 1560204000,
#    'precipProbability': 0.08,
#    'precipType': 'rain',
#    'temperatureHigh': 76.64,
#    'temperatureHighTime': 1560196800,
#    'temperatureLow': 55.65,
#    'temperatureLowTime': 1560247200,
#    'apparentTemperatureHigh': 76.64,
#    'apparentTemperatureHighTime': 1560196800,
#    'apparentTemperatureLow': 55.65,
#    'apparentTemperatureLowTime': 1560247200,
#    'dewPoint': 44.63,
#    'humidity': 0.49,
#    'pressure': 1020.91,
#    'windSpeed': 6.57,
#    'windGust': 23.24,
#    'windGustTime': 1560200400,
#    'windBearing': 300,
#    'cloudCover': 0.08,
#    'uvIndex': 8,
#    'uvIndexTime': 1560189600,
#    'visibility': 10,
#    'ozone': 367.41,
#    'temperatureMin': 53.61,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 76.64,
#    'temperatureMaxTime': 1560196800,
#    'apparentTemperatureMin': 53.61,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 76.64,
#    'apparentTemperatureMaxTime': 1560196800},
#   {'time': 1560229200,
#    'summary': 'Light rain starting in the evening.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0107,
#    'precipIntensityMax': 0.0351,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.9,
#    'precipType': 'rain',
#    'temperatureHigh': 70.45,
#    'temperatureHighTime': 1560272400,
#    'temperatureLow': 53.36,
#    'temperatureLowTime': 1560340800,
#    'apparentTemperatureHigh': 70.45,
#    'apparentTemperatureHighTime': 1560272400,
#    'apparentTemperatureLow': 53.36,
#    'apparentTemperatureLowTime': 1560340800,
#    'dewPoint': 49.81,
#    'humidity': 0.66,
#    'pressure': 1018.1,
#    'windSpeed': 4.61,
#    'windGust': 18.37,
#    'windGustTime': 1560308400,
#    'windBearing': 191,
#    'cloudCover': 0.65,
#    'uvIndex': 4,
#    'uvIndexTime': 1560268800,
#    'visibility': 9.96,
#    'ozone': 365.77,
#    'temperatureMin': 55.65,
#    'temperatureMinTime': 1560247200,
#    'temperatureMax': 70.45,
#    'temperatureMaxTime': 1560272400,
#    'apparentTemperatureMin': 55.65,
#    'apparentTemperatureMinTime': 1560247200,
#    'apparentTemperatureMax': 70.45,
#    'apparentTemperatureMaxTime': 1560272400},
#   {'time': 1560315600,
#    'summary': 'Mostly cloudy until evening and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0056,
#    'precipIntensityMax': 0.0217,
#    'precipIntensityMaxTime': 1560315600,
#    'precipProbability': 0.85,
#    'precipType': 'rain',
#    'temperatureHigh': 65.82,
#    'temperatureHighTime': 1560380400,
#    'temperatureLow': 47.39,
#    'temperatureLowTime': 1560420000,
#    'apparentTemperatureHigh': 65.82,
#    'apparentTemperatureHighTime': 1560380400,
#    'apparentTemperatureLow': 44.24,
#    'apparentTemperatureLowTime': 1560420000,
#    'dewPoint': 48.44,
#    'humidity': 0.7,
#    'pressure': 1012.53,
#    'windSpeed': 7.96,
#    'windGust': 24.99,
#    'windGustTime': 1560351600,
#    'windBearing': 349,
#    'cloudCover': 0.68,
#    'uvIndex': 5,
#    'uvIndexTime': 1560362400,
#    'visibility': 9.81,
#    'ozone': 381.77,
#    'temperatureMin': 53.36,
#    'temperatureMinTime': 1560340800,
#    'temperatureMax': 65.82,
#    'temperatureMaxTime': 1560380400,
#    'apparentTemperatureMin': 53.36,
#    'apparentTemperatureMinTime': 1560340800,
#    'apparentTemperatureMax': 65.82,
#    'apparentTemperatureMaxTime': 1560380400},
#   {'time': 1560402000,
#    'summary': 'Partly cloudy in the evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0003,
#    'precipIntensityMax': 0.0024,
#    'precipIntensityMaxTime': 1560459600,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperatureHigh': 70.72,
#    'temperatureHighTime': 1560470400,
#    'temperatureLow': 51.43,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 70.72,
#    'apparentTemperatureHighTime': 1560470400,
#    'apparentTemperatureLow': 51.43,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 40.9,
#    'humidity': 0.5,
#    'pressure': 1013.74,
#    'windSpeed': 7.36,
#    'windGust': 17.66,
#    'windGustTime': 1560459600,
#    'windBearing': 291,
#    'cloudCover': 0.06,
#    'uvIndex': 7,
#    'uvIndexTime': 1560445200,
#    'visibility': 10,
#    'ozone': 386.61,
#    'temperatureMin': 47.39,
#    'temperatureMinTime': 1560420000,
#    'temperatureMax': 70.72,
#    'temperatureMaxTime': 1560470400,
#    'apparentTemperatureMin': 44.24,
#    'apparentTemperatureMinTime': 1560420000,
#    'apparentTemperatureMax': 70.72,
#    'apparentTemperatureMaxTime': 1560470400},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0011,
#    'precipIntensityMax': 0.0044,
#    'precipIntensityMaxTime': 1560560400,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 74.61,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 52.81,
#    'temperatureLowTime': 1560596400,
#    'apparentTemperatureHigh': 74.61,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 52.81,
#    'apparentTemperatureLowTime': 1560596400,
#    'dewPoint': 46.2,
#    'humidity': 0.54,
#    'pressure': 1011.72,
#    'windSpeed': 2.61,
#    'windGust': 18.78,
#    'windGustTime': 1560571200,
#    'windBearing': 156,
#    'cloudCover': 0.3,
#    'uvIndex': 6,
#    'uvIndexTime': 1560535200,
#    'visibility': 10,
#    'ozone': 351.18,
#    'temperatureMin': 51.43,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 74.61,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 51.43,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 74.61,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0043,
#    'precipIntensityMaxTime': 1560621600,
#    'precipProbability': 0.46,
#    'precipType': 'rain',
#    'temperatureHigh': 72.98,
#    'temperatureHighTime': 1560636000,
#    'temperatureLow': 60.33,
#    'temperatureLowTime': 1560675600,
#    'apparentTemperatureHigh': 72.98,
#    'apparentTemperatureHighTime': 1560636000,
#    'apparentTemperatureLow': 60.33,
#    'apparentTemperatureLowTime': 1560675600,
#    'dewPoint': 51.32,
#    'humidity': 0.65,
#    'pressure': 1012.13,
#    'windSpeed': 7.11,
#    'windGust': 19.76,
#    'windGustTime': 1560607200,
#    'windBearing': 110,
#    'cloudCover': 0.63,
#    'uvIndex': 4,
#    'uvIndexTime': 1560614400,
#    'visibility': 10,
#    'ozone': 333.71,
#    'temperatureMin': 52.81,
#    'temperatureMinTime': 1560596400,
#    'temperatureMax': 72.98,
#    'temperatureMaxTime': 1560636000,
#    'apparentTemperatureMin': 52.81,
#    'apparentTemperatureMinTime': 1560596400,
#    'apparentTemperatureMax': 72.98,
#    'apparentTemperatureMaxTime': 1560636000},
#   {'time': 1560661200,
#    'summary': 'Mostly cloudy until afternoon.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560680796,
#    'sunsetTime': 1560736939,
#    'moonPhase': 0.48,
#    'precipIntensity': 0.0007,
#    'precipIntensityMax': 0.0019,
#    'precipIntensityMaxTime': 1560708000,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 75.82,
#    'temperatureHighTime': 1560722400,
#    'temperatureLow': 60.51,
#    'temperatureLowTime': 1560765600,
#    'apparentTemperatureHigh': 75.82,
#    'apparentTemperatureHighTime': 1560722400,
#    'apparentTemperatureLow': 60.51,
#    'apparentTemperatureLowTime': 1560765600,
#    'dewPoint': 54.85,
#    'humidity': 0.65,
#    'pressure': 1012.67,
#    'windSpeed': 3.61,
#    'windGust': 15.99,
#    'windGustTime': 1560722400,
#    'windBearing': 202,
#    'cloudCover': 0.37,
#    'uvIndex': 6,
#    'uvIndexTime': 1560715200,
#    'visibility': 10,
#    'ozone': 339.34,
#    'temperatureMin': 60.33,
#    'temperatureMinTime': 1560675600,
#    'temperatureMax': 75.82,
#    'temperatureMaxTime': 1560722400,
#    'apparentTemperatureMin': 60.33,
#    'apparentTemperatureMinTime': 1560675600,
#    'apparentTemperatureMax': 75.82,
#    'apparentTemperatureMaxTime': 1560722400},
#   {'time': 1560747600,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560767199,
#    'sunsetTime': 1560823361,
#    'moonPhase': 0.52,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0322,
#    'precipIntensityMaxTime': 1560772800,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 79.78,
#    'temperatureHighTime': 1560808800,
#    'temperatureLow': 62.22,
#    'temperatureLowTime': 1560852000,
#    'apparentTemperatureHigh': 79.78,
#    'apparentTemperatureHighTime': 1560808800,
#    'apparentTemperatureLow': 62.22,
#    'apparentTemperatureLowTime': 1560852000,
#    'dewPoint': 54.88,
#    'humidity': 0.6,
#    'pressure': 1012.8,
#    'windSpeed': 5.74,
#    'windGust': 9.53,
#    'windGustTime': 1560751200,
#    'windBearing': 267,
#    'cloudCover': 0.02,
#    'uvIndex': 9,
#    'uvIndexTime': 1560794400,
#    'visibility': 10,
#    'ozone': 339.67,
#    'temperatureMin': 60.51,
#    'temperatureMinTime': 1560765600,
#    'temperatureMax': 79.78,
#    'temperatureMaxTime': 1560808800,
#    'apparentTemperatureMin': 60.51,
#    'apparentTemperatureMinTime': 1560765600,
#    'apparentTemperatureMax': 79.78,
#    'apparentTemperatureMaxTime': 1560808800}],
#  [{'time': 1560142800,
#    'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0005,
#    'precipIntensityMax': 0.0022,
#    'precipIntensityMaxTime': 1560204000,
#    'precipProbability': 0.08,
#    'precipType': 'rain',
#    'temperatureHigh': 76.64,
#    'temperatureHighTime': 1560196800,
#    'temperatureLow': 55.65,
#    'temperatureLowTime': 1560247200,
#    'apparentTemperatureHigh': 76.64,
#    'apparentTemperatureHighTime': 1560196800,
#    'apparentTemperatureLow': 55.65,
#    'apparentTemperatureLowTime': 1560247200,
#    'dewPoint': 44.63,
#    'humidity': 0.49,
#    'pressure': 1020.91,
#    'windSpeed': 6.57,
#    'windGust': 23.24,
#    'windGustTime': 1560200400,
#    'windBearing': 300,
#    'cloudCover': 0.08,
#    'uvIndex': 8,
#    'uvIndexTime': 1560189600,
#    'visibility': 10,
#    'ozone': 367.41,
#    'temperatureMin': 53.61,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 76.64,
#    'temperatureMaxTime': 1560196800,
#    'apparentTemperatureMin': 53.61,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 76.64,
#    'apparentTemperatureMaxTime': 1560196800},
#   {'time': 1560229200,
#    'summary': 'Light rain starting in the evening.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0107,
#    'precipIntensityMax': 0.0351,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.9,
#    'precipType': 'rain',
#    'temperatureHigh': 70.45,
#    'temperatureHighTime': 1560272400,
#    'temperatureLow': 53.36,
#    'temperatureLowTime': 1560340800,
#    'apparentTemperatureHigh': 70.45,
#    'apparentTemperatureHighTime': 1560272400,
#    'apparentTemperatureLow': 53.36,
#    'apparentTemperatureLowTime': 1560340800,
#    'dewPoint': 49.81,
#    'humidity': 0.66,
#    'pressure': 1018.1,
#    'windSpeed': 4.61,
#    'windGust': 18.37,
#    'windGustTime': 1560308400,
#    'windBearing': 191,
#    'cloudCover': 0.65,
#    'uvIndex': 4,
#    'uvIndexTime': 1560268800,
#    'visibility': 9.96,
#    'ozone': 365.77,
#    'temperatureMin': 55.65,
#    'temperatureMinTime': 1560247200,
#    'temperatureMax': 70.45,
#    'temperatureMaxTime': 1560272400,
#    'apparentTemperatureMin': 55.65,
#    'apparentTemperatureMinTime': 1560247200,
#    'apparentTemperatureMax': 70.45,
#    'apparentTemperatureMaxTime': 1560272400},
#   {'time': 1560315600,
#    'summary': 'Mostly cloudy until evening and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0056,
#    'precipIntensityMax': 0.0217,
#    'precipIntensityMaxTime': 1560315600,
#    'precipProbability': 0.85,
#    'precipType': 'rain',
#    'temperatureHigh': 65.82,
#    'temperatureHighTime': 1560380400,
#    'temperatureLow': 47.39,
#    'temperatureLowTime': 1560420000,
#    'apparentTemperatureHigh': 65.82,
#    'apparentTemperatureHighTime': 1560380400,
#    'apparentTemperatureLow': 44.24,
#    'apparentTemperatureLowTime': 1560420000,
#    'dewPoint': 48.44,
#    'humidity': 0.7,
#    'pressure': 1012.53,
#    'windSpeed': 7.96,
#    'windGust': 24.99,
#    'windGustTime': 1560351600,
#    'windBearing': 349,
#    'cloudCover': 0.68,
#    'uvIndex': 5,
#    'uvIndexTime': 1560362400,
#    'visibility': 9.81,
#    'ozone': 381.77,
#    'temperatureMin': 53.36,
#    'temperatureMinTime': 1560340800,
#    'temperatureMax': 65.82,
#    'temperatureMaxTime': 1560380400,
#    'apparentTemperatureMin': 53.36,
#    'apparentTemperatureMinTime': 1560340800,
#    'apparentTemperatureMax': 65.82,
#    'apparentTemperatureMaxTime': 1560380400},
#   {'time': 1560402000,
#    'summary': 'Partly cloudy in the evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0003,
#    'precipIntensityMax': 0.0024,
#    'precipIntensityMaxTime': 1560459600,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperatureHigh': 70.72,
#    'temperatureHighTime': 1560470400,
#    'temperatureLow': 51.43,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 70.72,
#    'apparentTemperatureHighTime': 1560470400,
#    'apparentTemperatureLow': 51.43,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 40.9,
#    'humidity': 0.5,
#    'pressure': 1013.74,
#    'windSpeed': 7.36,
#    'windGust': 17.66,
#    'windGustTime': 1560459600,
#    'windBearing': 291,
#    'cloudCover': 0.06,
#    'uvIndex': 7,
#    'uvIndexTime': 1560445200,
#    'visibility': 10,
#    'ozone': 386.61,
#    'temperatureMin': 47.39,
#    'temperatureMinTime': 1560420000,
#    'temperatureMax': 70.72,
#    'temperatureMaxTime': 1560470400,
#    'apparentTemperatureMin': 44.24,
#    'apparentTemperatureMinTime': 1560420000,
#    'apparentTemperatureMax': 70.72,
#    'apparentTemperatureMaxTime': 1560470400},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0011,
#    'precipIntensityMax': 0.0044,
#    'precipIntensityMaxTime': 1560560400,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 74.61,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 52.81,
#    'temperatureLowTime': 1560596400,
#    'apparentTemperatureHigh': 74.61,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 52.81,
#    'apparentTemperatureLowTime': 1560596400,
#    'dewPoint': 46.2,
#    'humidity': 0.54,
#    'pressure': 1011.72,
#    'windSpeed': 2.61,
#    'windGust': 18.78,
#    'windGustTime': 1560571200,
#    'windBearing': 156,
#    'cloudCover': 0.3,
#    'uvIndex': 6,
#    'uvIndexTime': 1560535200,
#    'visibility': 10,
#    'ozone': 351.18,
#    'temperatureMin': 51.43,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 74.61,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 51.43,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 74.61,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0043,
#    'precipIntensityMaxTime': 1560621600,
#    'precipProbability': 0.46,
#    'precipType': 'rain',
#    'temperatureHigh': 72.98,
#    'temperatureHighTime': 1560636000,
#    'temperatureLow': 60.33,
#    'temperatureLowTime': 1560675600,
#    'apparentTemperatureHigh': 72.98,
#    'apparentTemperatureHighTime': 1560636000,
#    'apparentTemperatureLow': 60.33,
#    'apparentTemperatureLowTime': 1560675600,
#    'dewPoint': 51.32,
#    'humidity': 0.65,
#    'pressure': 1012.13,
#    'windSpeed': 7.11,
#    'windGust': 19.76,
#    'windGustTime': 1560607200,
#    'windBearing': 110,
#    'cloudCover': 0.63,
#    'uvIndex': 4,
#    'uvIndexTime': 1560614400,
#    'visibility': 10,
#    'ozone': 333.71,
#    'temperatureMin': 52.81,
#    'temperatureMinTime': 1560596400,
#    'temperatureMax': 72.98,
#    'temperatureMaxTime': 1560636000,
#    'apparentTemperatureMin': 52.81,
#    'apparentTemperatureMinTime': 1560596400,
#    'apparentTemperatureMax': 72.98,
#    'apparentTemperatureMaxTime': 1560636000},
#   {'time': 1560661200,
#    'summary': 'Mostly cloudy until afternoon.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560680796,
#    'sunsetTime': 1560736939,
#    'moonPhase': 0.48,
#    'precipIntensity': 0.0007,
#    'precipIntensityMax': 0.0019,
#    'precipIntensityMaxTime': 1560708000,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 75.82,
#    'temperatureHighTime': 1560722400,
#    'temperatureLow': 60.51,
#    'temperatureLowTime': 1560765600,
#    'apparentTemperatureHigh': 75.82,
#    'apparentTemperatureHighTime': 1560722400,
#    'apparentTemperatureLow': 60.51,
#    'apparentTemperatureLowTime': 1560765600,
#    'dewPoint': 54.85,
#    'humidity': 0.65,
#    'pressure': 1012.67,
#    'windSpeed': 3.61,
#    'windGust': 15.99,
#    'windGustTime': 1560722400,
#    'windBearing': 202,
#    'cloudCover': 0.37,
#    'uvIndex': 6,
#    'uvIndexTime': 1560715200,
#    'visibility': 10,
#    'ozone': 339.34,
#    'temperatureMin': 60.33,
#    'temperatureMinTime': 1560675600,
#    'temperatureMax': 75.82,
#    'temperatureMaxTime': 1560722400,
#    'apparentTemperatureMin': 60.33,
#    'apparentTemperatureMinTime': 1560675600,
#    'apparentTemperatureMax': 75.82,
#    'apparentTemperatureMaxTime': 1560722400},
#   {'time': 1560747600,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560767199,
#    'sunsetTime': 1560823361,
#    'moonPhase': 0.52,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0322,
#    'precipIntensityMaxTime': 1560772800,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 79.78,
#    'temperatureHighTime': 1560808800,
#    'temperatureLow': 62.22,
#    'temperatureLowTime': 1560852000,
#    'apparentTemperatureHigh': 79.78,
#    'apparentTemperatureHighTime': 1560808800,
#    'apparentTemperatureLow': 62.22,
#    'apparentTemperatureLowTime': 1560852000,
#    'dewPoint': 54.88,
#    'humidity': 0.6,
#    'pressure': 1012.8,
#    'windSpeed': 5.74,
#    'windGust': 9.53,
#    'windGustTime': 1560751200,
#    'windBearing': 267,
#    'cloudCover': 0.02,
#    'uvIndex': 9,
#    'uvIndexTime': 1560794400,
#    'visibility': 10,
#    'ozone': 339.67,
#    'temperatureMin': 60.51,
#    'temperatureMinTime': 1560765600,
#    'temperatureMax': 79.78,
#    'temperatureMaxTime': 1560808800,
#    'apparentTemperatureMin': 60.51,
#    'apparentTemperatureMinTime': 1560765600,
#    'apparentTemperatureMax': 79.78,
#    'apparentTemperatureMaxTime': 1560808800}],
#  [{'time': 1560142800,
#    'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0005,
#    'precipIntensityMax': 0.0022,
#    'precipIntensityMaxTime': 1560204000,
#    'precipProbability': 0.08,
#    'precipType': 'rain',
#    'temperatureHigh': 76.64,
#    'temperatureHighTime': 1560196800,
#    'temperatureLow': 55.65,
#    'temperatureLowTime': 1560247200,
#    'apparentTemperatureHigh': 76.64,
#    'apparentTemperatureHighTime': 1560196800,
#    'apparentTemperatureLow': 55.65,
#    'apparentTemperatureLowTime': 1560247200,
#    'dewPoint': 44.63,
#    'humidity': 0.49,
#    'pressure': 1020.91,
#    'windSpeed': 6.57,
#    'windGust': 23.24,
#    'windGustTime': 1560200400,
#    'windBearing': 300,
#    'cloudCover': 0.08,
#    'uvIndex': 8,
#    'uvIndexTime': 1560189600,
#    'visibility': 10,
#    'ozone': 367.41,
#    'temperatureMin': 53.61,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 76.64,
#    'temperatureMaxTime': 1560196800,
#    'apparentTemperatureMin': 53.61,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 76.64,
#    'apparentTemperatureMaxTime': 1560196800},
#   {'time': 1560229200,
#    'summary': 'Light rain starting in the evening.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0107,
#    'precipIntensityMax': 0.0351,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.9,
#    'precipType': 'rain',
#    'temperatureHigh': 70.45,
#    'temperatureHighTime': 1560272400,
#    'temperatureLow': 53.36,
#    'temperatureLowTime': 1560340800,
#    'apparentTemperatureHigh': 70.45,
#    'apparentTemperatureHighTime': 1560272400,
#    'apparentTemperatureLow': 53.36,
#    'apparentTemperatureLowTime': 1560340800,
#    'dewPoint': 49.81,
#    'humidity': 0.66,
#    'pressure': 1018.1,
#    'windSpeed': 4.61,
#    'windGust': 18.37,
#    'windGustTime': 1560308400,
#    'windBearing': 191,
#    'cloudCover': 0.65,
#    'uvIndex': 4,
#    'uvIndexTime': 1560268800,
#    'visibility': 9.96,
#    'ozone': 365.77,
#    'temperatureMin': 55.65,
#    'temperatureMinTime': 1560247200,
#    'temperatureMax': 70.45,
#    'temperatureMaxTime': 1560272400,
#    'apparentTemperatureMin': 55.65,
#    'apparentTemperatureMinTime': 1560247200,
#    'apparentTemperatureMax': 70.45,
#    'apparentTemperatureMaxTime': 1560272400},
#   {'time': 1560315600,
#    'summary': 'Mostly cloudy until evening and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0056,
#    'precipIntensityMax': 0.0217,
#    'precipIntensityMaxTime': 1560315600,
#    'precipProbability': 0.85,
#    'precipType': 'rain',
#    'temperatureHigh': 65.82,
#    'temperatureHighTime': 1560380400,
#    'temperatureLow': 47.39,
#    'temperatureLowTime': 1560420000,
#    'apparentTemperatureHigh': 65.82,
#    'apparentTemperatureHighTime': 1560380400,
#    'apparentTemperatureLow': 44.24,
#    'apparentTemperatureLowTime': 1560420000,
#    'dewPoint': 48.44,
#    'humidity': 0.7,
#    'pressure': 1012.53,
#    'windSpeed': 7.96,
#    'windGust': 24.99,
#    'windGustTime': 1560351600,
#    'windBearing': 349,
#    'cloudCover': 0.68,
#    'uvIndex': 5,
#    'uvIndexTime': 1560362400,
#    'visibility': 9.81,
#    'ozone': 381.77,
#    'temperatureMin': 53.36,
#    'temperatureMinTime': 1560340800,
#    'temperatureMax': 65.82,
#    'temperatureMaxTime': 1560380400,
#    'apparentTemperatureMin': 53.36,
#    'apparentTemperatureMinTime': 1560340800,
#    'apparentTemperatureMax': 65.82,
#    'apparentTemperatureMaxTime': 1560380400},
#   {'time': 1560402000,
#    'summary': 'Partly cloudy in the evening.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0003,
#    'precipIntensityMax': 0.0024,
#    'precipIntensityMaxTime': 1560459600,
#    'precipProbability': 0.03,
#    'precipType': 'rain',
#    'temperatureHigh': 70.72,
#    'temperatureHighTime': 1560470400,
#    'temperatureLow': 51.43,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 70.72,
#    'apparentTemperatureHighTime': 1560470400,
#    'apparentTemperatureLow': 51.43,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 40.9,
#    'humidity': 0.5,
#    'pressure': 1013.74,
#    'windSpeed': 7.36,
#    'windGust': 17.66,
#    'windGustTime': 1560459600,
#    'windBearing': 291,
#    'cloudCover': 0.06,
#    'uvIndex': 7,
#    'uvIndexTime': 1560445200,
#    'visibility': 10,
#    'ozone': 386.61,
#    'temperatureMin': 47.39,
#    'temperatureMinTime': 1560420000,
#    'temperatureMax': 70.72,
#    'temperatureMaxTime': 1560470400,
#    'apparentTemperatureMin': 44.24,
#    'apparentTemperatureMinTime': 1560420000,
#    'apparentTemperatureMax': 70.72,
#    'apparentTemperatureMaxTime': 1560470400},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0011,
#    'precipIntensityMax': 0.0044,
#    'precipIntensityMaxTime': 1560560400,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 74.61,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 52.81,
#    'temperatureLowTime': 1560596400,
#    'apparentTemperatureHigh': 74.61,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 52.81,
#    'apparentTemperatureLowTime': 1560596400,
#    'dewPoint': 46.2,
#    'humidity': 0.54,
#    'pressure': 1011.72,
#    'windSpeed': 2.61,
#    'windGust': 18.78,
#    'windGustTime': 1560571200,
#    'windBearing': 156,
#    'cloudCover': 0.3,
#    'uvIndex': 6,
#    'uvIndexTime': 1560535200,
#    'visibility': 10,
#    'ozone': 351.18,
#    'temperatureMin': 51.43,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 74.61,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 51.43,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 74.61,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0043,
#    'precipIntensityMaxTime': 1560621600,
#    'precipProbability': 0.46,
#    'precipType': 'rain',
#    'temperatureHigh': 72.98,
#    'temperatureHighTime': 1560636000,
#    'temperatureLow': 60.33,
#    'temperatureLowTime': 1560675600,
#    'apparentTemperatureHigh': 72.98,
#    'apparentTemperatureHighTime': 1560636000,
#    'apparentTemperatureLow': 60.33,
#    'apparentTemperatureLowTime': 1560675600,
#    'dewPoint': 51.32,
#    'humidity': 0.65,
#    'pressure': 1012.13,
#    'windSpeed': 7.11,
#    'windGust': 19.76,
#    'windGustTime': 1560607200,
#    'windBearing': 110,
#    'cloudCover': 0.63,
#    'uvIndex': 4,
#    'uvIndexTime': 1560614400,
#    'visibility': 10,
#    'ozone': 333.71,
#    'temperatureMin': 52.81,
#    'temperatureMinTime': 1560596400,
#    'temperatureMax': 72.98,
#    'temperatureMaxTime': 1560636000,
#    'apparentTemperatureMin': 52.81,
#    'apparentTemperatureMinTime': 1560596400,
#    'apparentTemperatureMax': 72.98,
#    'apparentTemperatureMaxTime': 1560636000},
#   {'time': 1560661200,
#    'summary': 'Mostly cloudy until afternoon.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560680796,
#    'sunsetTime': 1560736939,
#    'moonPhase': 0.48,
#    'precipIntensity': 0.0007,
#    'precipIntensityMax': 0.0019,
#    'precipIntensityMaxTime': 1560708000,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 75.82,
#    'temperatureHighTime': 1560722400,
#    'temperatureLow': 60.51,
#    'temperatureLowTime': 1560765600,
#    'apparentTemperatureHigh': 75.82,
#    'apparentTemperatureHighTime': 1560722400,
#    'apparentTemperatureLow': 60.51,
#    'apparentTemperatureLowTime': 1560765600,
#    'dewPoint': 54.85,
#    'humidity': 0.65,
#    'pressure': 1012.67,
#    'windSpeed': 3.61,
#    'windGust': 15.99,
#    'windGustTime': 1560722400,
#    'windBearing': 202,
#    'cloudCover': 0.37,
#    'uvIndex': 6,
#    'uvIndexTime': 1560715200,
#    'visibility': 10,
#    'ozone': 339.34,
#    'temperatureMin': 60.33,
#    'temperatureMinTime': 1560675600,
#    'temperatureMax': 75.82,
#    'temperatureMaxTime': 1560722400,
#    'apparentTemperatureMin': 60.33,
#    'apparentTemperatureMinTime': 1560675600,
#    'apparentTemperatureMax': 75.82,
#    'apparentTemperatureMaxTime': 1560722400},
#   {'time': 1560747600,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560767199,
#    'sunsetTime': 1560823361,
#    'moonPhase': 0.52,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0322,
#    'precipIntensityMaxTime': 1560772800,
#    'precipProbability': 0.11,
#    'precipType': 'rain',
#    'temperatureHigh': 79.78,
#    'temperatureHighTime': 1560808800,
#    'temperatureLow': 62.22,
#    'temperatureLowTime': 1560852000,
#    'apparentTemperatureHigh': 79.78,
#    'apparentTemperatureHighTime': 1560808800,
#    'apparentTemperatureLow': 62.22,
#    'apparentTemperatureLowTime': 1560852000,
#    'dewPoint': 54.88,
#    'humidity': 0.6,
#    'pressure': 1012.8,
#    'windSpeed': 5.74,
#    'windGust': 9.53,
#    'windGustTime': 1560751200,
#    'windBearing': 267,
#    'cloudCover': 0.02,
#    'uvIndex': 9,
#    'uvIndexTime': 1560794400,
#    'visibility': 10,
#    'ozone': 339.67,
#    'temperatureMin': 60.51,
#    'temperatureMinTime': 1560765600,
#    'temperatureMax': 79.78,
#    'temperatureMaxTime': 1560808800,
#    'apparentTemperatureMin': 60.51,
#    'apparentTemperatureMinTime': 1560765600,
#    'apparentTemperatureMax': 79.78,
#    'apparentTemperatureMaxTime': 1560808800}]]

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
for time in daily_stuff:
    for yikes in time:
        print(f"for {yikes['time']} the high temperature is {yikes['temperatureHigh']}")
        if yikes['temperatureHigh'] > 75:
            print("it's hot!")
        elif yikes['temperatureHigh'] > 60:
            print("it's warm!")
        else:
            print("it's cold!")
# Out:
# for 1560142800 the high temperature is 76.64
# it's hot!
# for 1560229200 the high temperature is 70.45
# it's warm!
# for 1560315600 the high temperature is 65.82
# it's warm!
# for 1560402000 the high temperature is 70.72
# it's warm!
# for 1560488400 the high temperature is 74.61
# it's warm!
# for 1560574800 the high temperature is 72.98
# it's warm!
# for 1560661200 the high temperature is 75.82
# it's hot!
# for 1560747600 the high temperature is 79.78
# it's hot!
# for 1560142800 the high temperature is 76.64
# it's hot!
# for 1560229200 the high temperature is 70.45
# it's warm!
# for 1560315600 the high temperature is 65.82
# it's warm!
# for 1560402000 the high temperature is 70.72
# it's warm!
# for 1560488400 the high temperature is 74.61
# it's warm!
# for 1560574800 the high temperature is 72.98
# it's warm!
# for 1560661200 the high temperature is 75.82
# it's hot!
# for 1560747600 the high temperature is 79.78
# it's hot!
# for 1560142800 the high temperature is 76.64
# it's hot!
# for 1560229200 the high temperature is 70.45
# it's warm!
# for 1560315600 the high temperature is 65.82
# it's warm!
# for 1560402000 the high temperature is 70.72
# it's warm!
# for 1560488400 the high temperature is 74.61
# it's warm!
# for 1560574800 the high temperature is 72.98
# it's warm!
# for 1560661200 the high temperature is 75.82
# it's hot!
# for 1560747600 the high temperature is 79.78
# it's hot!

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
hottest_day=0
hottest_temp=0
for time in daily_stuff:
    for yikes in time:
        if yikes['temperatureHigh'] > hottest_temp:
            hottest_temp = yikes['temperatureHigh']
            hottest_day = yikes['time']

# %%
hottest_day = datetime.utcfromtimestamp(int(hottest_day)).strftime('%Y-%m-%d %H:%M')

# %%
hottest_day
# Out:
# '2019-06-17 05:00'

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
#25.7617° N, 80.1918° W (miami)
url_miami =f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918'

# %%
data_miami = requests.get(url_miami).json()

# %%
miami = data_miami['hourly']['data']

# %%
for hour in miami:
    print(f"for {hour['time']}, temperature is {hour['temperature']}")
    if hour['cloudCover'] > .50:
        print("and cloudy")
# Out:
# for 1560182400, temperature is 77.45
# and cloudy
# for 1560186000, temperature is 78.24
# and cloudy
# for 1560189600, temperature is 83.68
# and cloudy
# for 1560193200, temperature is 87.49
# and cloudy
# for 1560196800, temperature is 88.19
# and cloudy
# for 1560200400, temperature is 88.71
# and cloudy
# for 1560204000, temperature is 87.59
# and cloudy
# for 1560207600, temperature is 85.99
# and cloudy
# for 1560211200, temperature is 84.13
# and cloudy
# for 1560214800, temperature is 82.97
# and cloudy
# for 1560218400, temperature is 82.29
# and cloudy
# for 1560222000, temperature is 81.73
# and cloudy
# for 1560225600, temperature is 81.2
# for 1560229200, temperature is 80.79
# for 1560232800, temperature is 80.99
# for 1560236400, temperature is 80.51
# for 1560240000, temperature is 79.76
# for 1560243600, temperature is 79.37
# for 1560247200, temperature is 79.53
# and cloudy
# for 1560250800, temperature is 80.35
# and cloudy
# for 1560254400, temperature is 81.7
# and cloudy
# for 1560258000, temperature is 83.95
# and cloudy
# for 1560261600, temperature is 85.8
# and cloudy
# for 1560265200, temperature is 87.05
# and cloudy
# for 1560268800, temperature is 88.01
# and cloudy
# for 1560272400, temperature is 88.71
# and cloudy
# for 1560276000, temperature is 89.46
# and cloudy
# for 1560279600, temperature is 90.24
# and cloudy
# for 1560283200, temperature is 90.25
# and cloudy
# for 1560286800, temperature is 89.37
# and cloudy
# for 1560290400, temperature is 88.21
# for 1560294000, temperature is 86.62
# for 1560297600, temperature is 85.29
# for 1560301200, temperature is 84.39
# for 1560304800, temperature is 83.74
# and cloudy
# for 1560308400, temperature is 82.93
# and cloudy
# for 1560312000, temperature is 82.24
# and cloudy
# for 1560315600, temperature is 81.63
# for 1560319200, temperature is 81.17
# for 1560322800, temperature is 80.59
# for 1560326400, temperature is 80
# and cloudy
# for 1560330000, temperature is 80.04
# and cloudy
# for 1560333600, temperature is 80.63
# and cloudy
# for 1560337200, temperature is 81.52
# and cloudy
# for 1560340800, temperature is 83.11
# and cloudy
# for 1560344400, temperature is 85.06
# for 1560348000, temperature is 86.83
# for 1560351600, temperature is 88.2
# for 1560355200, temperature is 89.18

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
above_85 =0
total_hours =len(miami)

# %%
for hour in miami:
    if hour['temperature'] > 85: 
        above_85+=1
print(f"{round(above_85/total_hours*100)}%")
# Out:
# 41%

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
#https://api.darksky.net/forecast/[key]/[latitude],[longitude],[time]
#central park longitude and latitude 40.7829° N, 73.9654° W
#Either be a UNIX time (that is, seconds since midnight GMT on 1 Jan 1970) 
#or a string formatted as follows: [YYYY]-[MM]-[DD]T[HH]:[MM]:[SS][timezone].
YYYY = 2012
MM = '12'
DD = '31'


url_cp =f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,{YYYY}-{MM}-{DD}T00:00:00'

# %%
data_cp= requests.get(url_cp).json()

# %%
data_cp
# Out:
# {'code': 400, 'error': 'An invalid time was specified.'}

# %%
data_cp['currently']['temperature']
# Out:
# 27.85

# %%
YYYY=2007
url_cp_2 =f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,{YYYY}-{MM}-{DD}T00:00:00'
print(url_cp_2)
# Out:
# https://api.darksky.net/forecast/4649d20cd19eee86c32687a69f52254e/40.7829,-73.9654,2007-12-31T00:00:00

# %%
data_cp= requests.get(url_cp_2).json()
data_cp['currently']['temperature']
# Out:
# 37.3

# %%
YYYY=2005
url_cp_3 =f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,{YYYY}-{MM}-{DD}T00:00:00'
print(url_cp_3)
# Out:
# https://api.darksky.net/forecast/4649d20cd19eee86c32687a69f52254e/40.7829,-73.9654,2005-12-31T00:00:00

# %%
data_cp= requests.get(url_cp_3).json()
data_cp['currently']['temperature']
# Out:
# 32.17

# %%
#just played with numbers
YYYY = 1936
MM = '01'
DD = '01'
url_cp =f'https://api.darksky.net/forecast/{API_KEY}/40.7829,-73.9654,{YYYY}-{MM}-{DD}T00:00:00'
data_cp= requests.get(url_cp).json()
print(data_cp['currently'])
# Out:
# {'time': -1072983600, 'uvIndex': 0}
