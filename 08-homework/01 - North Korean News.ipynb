# %% [markdown]
# # North Korean News
#
# Scrape the North Korean news agency http://kcna.kp
#
# Save a CSV called `nk-news.csv`. This file should include:
#
# * The **article headline**
# * The value of **`onclick`** (they don't have normal links)
# * The **article ID** (for example, the article ID for `fn_showArticle("AR0125885", "", "NT00", "L")` is `AR0125885`
#
# The last part is easiest using pandas. Be sure you don't save the index!
#
# * _**Tip:** If you're using requests+BeautifulSoup, you can always look at response.text to see if the page looks like what you think it looks like_
# * _**Tip:** Check your URL to make sure it is what you think it should be!_
# * _**Tip:** Does it look different if you scrape with BeautifulSoup compared to if you scrape it with Selenium?_
# * _**Tip:** For the last part, how do you pull out part of a string from a longer string?_
# * _**Tip:** `expand=False` is helpful if you want to assign a single new column when extracting_
# * _**Tip:** `(` and `)` mean something special in regular expressions, so you have to say "no really seriously I mean `(`" by using `\(` instead_
# * _**Tip:** if your `.*` is taking up too much stuff, you can try `.*?` instead, which instead of "take as much as possible" it means "take only as much as needed"_

# %%
import pandas as pd
import requests
import re
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %matplotlib inline

# %%
my_url= 'http://kcna.kp/kcna.user.home.retrieveHomeInfoList.kcmsf'
raw_html = requests.get(my_url)

# %%
# soup_doc = BeautifulSoup(raw_html, 'html.parser')
# print(soup_doc.text)

# %%
doc = BeautifulSoup(raw_html.text)

# %%
headlines = doc.find_all(class_='titlebet')

# %%
print(headlines)
# Out:
# [<a class="titlebet" href="#this" onclick='fn_showArticle("AR0126135", "", "NT00", "L")'><nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문을 보내시였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126133", "", "NT00", "L")'>경애하는 최고령도자 <nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문과 조화를 보내시였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126098", "", "NT00", "L")'><nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께서 로씨야대통령에게 축전을 보내시였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0125885", "", "NT00", "L")'>경애하는 최고령도자 <nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께서 조선인민군 제2기 제7차 군인가족예술소조경연에서 당선된 군부대들의 군인가족예술소조원들과 기념사진을 찍으시였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0125876", "", "NT00", "L")'><nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께서 꾸바공산당 중앙위원회 제1비서에게 축전을 보내시였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0125856", "", "NT00", "L")'>대집단체조와 예술공연 《인민의 나라》 개막</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126318", "", "NT41", "L")'>중앙미술전시회 개막</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126314", "", "NT41", "L")'>중앙연구토론회 진행</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126313", "", "NT41", "L")'><nobr><strong><font style="font-size:10pt;">김일성</font></strong></nobr>동지와 <nobr><strong><font style="font-size:10pt;">김정일</font></strong></nobr>동지의 동상을 찾아 총련 지바현상공회대표단 경모의 정 표시</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126312", "", "NT41", "L")'>총련 지바현상공회대표단 도착</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126310", "", "NT41", "L")'>정방산이 전하는 이야기</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126309", "", "NT41", "L")'>남조선단체들 민족분렬을 끝장내기 위한 투쟁에 나설것을 호소</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126298", "", "NT41", "L")'>남조선단체들 4.27판문점선언과 9월평양공동선언의 전면적리행을 요구</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126297", "", "NT41", "L")'>환경보호에 이바지할 연구성과들</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126296", "", "NT41", "L")'>천수백만t의 석탄매장량 탐사</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126295", "", "NT41", "L")'>최룡해동지 세이쉘공화국 국경절을 축하</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126293", "", "NT41", "L")'>《로동신문》 혁명과 건설에서 주체성과 민족성을 고수해나갈데 대해 강조</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126292", "", "NT41", "L")'>주체108(2019)년 6월 18일 신문개관</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126291", "", "NT41", "L")'>선물동물들의 마리수가 늘어난다--중앙동물원에서</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126290", "", "NT41", "L")'>6.12조미공동성명채택 1돐에 즈음하여 로씨야,알제리인사 담화 발표</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126289", "", "NT41", "L")'><nobr><strong><font style="font-size:10pt;">김일성</font></strong></nobr>주석회고위원회 쿠웨이트에서 결성</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126288", "", "NT41", "L")'><nobr><strong><font style="font-size:10pt;">김일성</font></strong></nobr>주석회고 수리아통일사회주의자당위원회 결성</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126287", "", "NT41", "L")'><nobr><strong><font style="font-size:10pt;">김정은</font></strong></nobr>동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126286", "", "NT41", "L")'>중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126285", "", "NT41", "L")'>평안남도양생원 새로 건설</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126284", "", "NT41", "L")'>조선에서 적십자활동 활발</a>, <a class="titlebet" href="#this" onclick='fn_showArticle("AR0126283", "", "NT41", "L")'>평양국제건강 및 의료기구부문 과학기술전시회 개막</a>, <a clas ...

# %%
rows=[]
for head in headlines:
    row = {}
    try:   
        row['article']=(head.text)
    except:
        continue
    row['onclick']=(head["onclick"])
    row['article_id']=(head["onclick"][16:25])
    rows.append(row)

# %%
print(rows)
# Out:
# [{'article': '김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문을 보내시였다', 'onclick': 'fn_showArticle("AR0126135", "", "NT00", "L")', 'article_id': 'AR0126135'}, {'article': '경애하는 최고령도자 김정은동지께서 김대중 전 대통령의 부인 리희호녀사의 유가족들에게 조의문과 조화를 보내시였다', 'onclick': 'fn_showArticle("AR0126133", "", "NT00", "L")', 'article_id': 'AR0126133'}, {'article': '김정은동지께서 로씨야대통령에게 축전을 보내시였다', 'onclick': 'fn_showArticle("AR0126098", "", "NT00", "L")', 'article_id': 'AR0126098'}, {'article': '경애하는 최고령도자 김정은동지께서 조선인민군 제2기 제7차 군인가족예술소조경연에서 당선된 군부대들의 군인가족예술소조원들과 기념사진을 찍으시였다', 'onclick': 'fn_showArticle("AR0125885", "", "NT00", "L")', 'article_id': 'AR0125885'}, {'article': '김정은동지께서 꾸바공산당 중앙위원회 제1비서에게 축전을 보내시였다', 'onclick': 'fn_showArticle("AR0125876", "", "NT00", "L")', 'article_id': 'AR0125876'}, {'article': '대집단체조와 예술공연 《인민의 나라》 개막', 'onclick': 'fn_showArticle("AR0125856", "", "NT00", "L")', 'article_id': 'AR0125856'}, {'article': '중앙미술전시회 개막', 'onclick': 'fn_showArticle("AR0126318", "", "NT41", "L")', 'article_id': 'AR0126318'}, {'article': '중앙연구토론회 진행', 'onclick': 'fn_showArticle("AR0126314", "", "NT41", "L")', 'article_id': 'AR0126314'}, {'article': '김일성동지와 김정일동지의 동상을 찾아 총련 지바현상공회대표단 경모의 정 표시', 'onclick': 'fn_showArticle("AR0126313", "", "NT41", "L")', 'article_id': 'AR0126313'}, {'article': '총련 지바현상공회대표단 도착', 'onclick': 'fn_showArticle("AR0126312", "", "NT41", "L")', 'article_id': 'AR0126312'}, {'article': '정방산이 전하는 이야기', 'onclick': 'fn_showArticle("AR0126310", "", "NT41", "L")', 'article_id': 'AR0126310'}, {'article': '남조선단체들 민족분렬을 끝장내기 위한 투쟁에 나설것을 호소', 'onclick': 'fn_showArticle("AR0126309", "", "NT41", "L")', 'article_id': 'AR0126309'}, {'article': '남조선단체들 4.27판문점선언과 9월평양공동선언의 전면적리행을 요구', 'onclick': 'fn_showArticle("AR0126298", "", "NT41", "L")', 'article_id': 'AR0126298'}, {'article': '환경보호에 이바지할 연구성과들', 'onclick': 'fn_showArticle("AR0126297", "", "NT41", "L")', 'article_id': 'AR0126297'}, {'article': '천수백만t의 석탄매장량 탐사', 'onclick': 'fn_showArticle("AR0126296", "", "NT41", "L")', 'article_id': 'AR0126296'}, {'article': '최룡해동지 세이쉘공화국 국경절을 축하', 'onclick': 'fn_showArticle("AR0126295", "", "NT41", "L")', 'article_id': 'AR0126295'}, {'article': '《로동신문》 혁명과 건설에서 주체성과 민족성을 고수해나갈데 대해 강조', 'onclick': 'fn_showArticle("AR0126293", "", "NT41", "L")', 'article_id': 'AR0126293'}, {'article': '주체108(2019)년 6월 18일 신문개관', 'onclick': 'fn_showArticle("AR0126292", "", "NT41", "L")', 'article_id': 'AR0126292'}, {'article': '선물동물들의 마리수가 늘어난다--중앙동물원에서', 'onclick': 'fn_showArticle("AR0126291", "", "NT41", "L")', 'article_id': 'AR0126291'}, {'article': '6.12조미공동성명채택 1돐에 즈음하여 로씨야,알제리인사 담화 발표', 'onclick': 'fn_showArticle("AR0126290", "", "NT41", "L")', 'article_id': 'AR0126290'}, {'article': '김일성주석회고위원회 쿠웨이트에서 결성', 'onclick': 'fn_showArticle("AR0126289", "", "NT41", "L")', 'article_id': 'AR0126289'}, {'article': '김일성주석회고 수리아통일사회주의자당위원회 결성', 'onclick': 'fn_showArticle("AR0126288", "", "NT41", "L")', 'article_id': 'AR0126288'}, {'article': '김정은동지께 베네수엘라 까라보보주 나구아나구아시가 최고훈장을 수여해드리였다', 'onclick': 'fn_showArticle("AR0126287", "", "NT41", "L")', 'article_id': 'AR0126287'}, {'article': '중국공산당 중앙위원회 총서기,중화인민공화국 주석 습근평동지가 조선을 방문한다', 'onclick': 'fn_showArticle("AR0126286", "", "NT41", "L")', 'article_id': 'AR0126286'}, {'article': '평안남도양생원 새로 건설', 'onclick': 'fn_showArticle("AR0126285", "", "NT41", "L")', 'article_id': 'AR0126285'}, {'article': '조선에서 적십자활동 활발', 'onclick': 'fn_showArticle("AR0126284", "", "NT41", "L")', 'article_id': 'AR0126284'}, {'article': '평양국제건강 및 의료기구부문 과학기술전시회 개막', 'onclick': 'fn_showArticle("AR0126283", "", "NT41", "L")', 'article_id': 'AR0126283'}, {'article': '조선정부대표단 나이제리아방문을 마치고 귀국', 'onclick': 'fn_showArticle("AR0126282", "", "NT41", "L")', 'article_id': 'AR0126282'}, {'article': '김재룡동지 덕천지구탄광련합기업소 현지료해', 'onclick': 'fn_showArticle("AR0126281", "", "NT41", "L")', 'article_id': 'AR0126281'}, {'article': '김정은각하의 존함은 인류의 보호자,은인으로 길이 빛날것이라고 여러 나라 인사들 칭송', 'onclick': 'fn_showArticle("AR0126280", "", "NT41", "L")', 'article_id': 'AR0126280'}, {'article': '100여만마리의 새끼가재미 방류', ' ...

# %%
df = pd.DataFrame(rows)

# %%
df.to_csv('nk-news.csv',index=False)
