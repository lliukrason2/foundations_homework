# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests
from datetime import datetime

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
#one time make a .env
# !touch .env

# %%
API_KEY = os.getenv("DARKSKY_API_KEY")

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
#44.9537° N, 93.0900° W
url=f'https://api.darksky.net/forecast/{API_KEY}/44.9537,-93.0900'

# %%
data = requests.get(url).json()

# %%
data['currently']
# Out:
# {'time': 1560022778,
#  'summary': 'Clear',
#  'icon': 'clear-day',
#  'nearestStormDistance': 125,
#  'nearestStormBearing': 237,
#  'precipIntensity': 0,
#  'precipProbability': 0,
#  'temperature': 85.01,
#  'apparentTemperature': 85.01,
#  'dewPoint': 52.67,
#  'humidity': 0.33,
#  'pressure': 1012.75,
#  'windSpeed': 11.1,
#  'windGust': 17.44,
#  'windBearing': 153,
#  'cloudCover': 0,
#  'uvIndex': 8,
#  'visibility': 10,
#  'ozone': 315.31}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
#current wind speed
data['currently']['windSpeed']
# Out:
# 11.1

# %%
data['currently']['temperature']-data['currently']['apparentTemperature']
# Out:
# 0.0

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
daily_forecast=data['daily']

# %%
daily_data=daily_forecast['data'][0]

# %%
daily_data['moonPhase']
# Out:
# 0.19

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
daily_data['temperatureHigh']-daily_data['temperatureLow']
# Out:
# 22.04

# %%
daily_forecast
# Out:
# {'summary': 'Light rain on Tuesday through next Saturday, with high temperatures falling to 63°F on Wednesday.',
#  'icon': 'rain',
#  'data': [{'time': 1559970000,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1559989660,
#    'sunsetTime': 1560045488,
#    'moonPhase': 0.19,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.002,
#    'precipIntensityMaxTime': 1560038400,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperatureHigh': 85.8,
#    'temperatureHighTime': 1560031200,
#    'temperatureLow': 63.76,
#    'temperatureLowTime': 1560078000,
#    'apparentTemperatureHigh': 85.8,
#    'apparentTemperatureHighTime': 1560031200,
#    'apparentTemperatureLow': 63.76,
#    'apparentTemperatureLowTime': 1560078000,
#    'dewPoint': 55.55,
#    'humidity': 0.49,
#    'pressure': 1013.25,
#    'windSpeed': 9.05,
#    'windGust': 20.89,
#    'windGustTime': 1560052800,
#    'windBearing': 153,
#    'cloudCover': 0,
#    'uvIndex': 9,
#    'uvIndexTime': 1560013200,
#    'visibility': 9.98,
#    'ozone': 313.04,
#    'temperatureMin': 67.95,
#    'temperatureMinTime': 1559991600,
#    'temperatureMax': 85.8,
#    'temperatureMaxTime': 1560031200,
#    'apparentTemperatureMin': 67.95,
#    'apparentTemperatureMinTime': 1559991600,
#    'apparentTemperatureMax': 85.8,
#    'apparentTemperatureMaxTime': 1560031200},
#   {'time': 1560056400,
#    'summary': 'Mostly cloudy throughout the day and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560076044,
#    'sunsetTime': 1560131927,
#    'moonPhase': 0.23,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0035,
#    'precipIntensityMaxTime': 1560106800,
#    'precipProbability': 0.2,
#    'precipType': 'rain',
#    'temperatureHigh': 69.57,
#    'temperatureHighTime': 1560092400,
#    'temperatureLow': 53.97,
#    'temperatureLowTime': 1560164400,
#    'apparentTemperatureHigh': 69.59,
#    'apparentTemperatureHighTime': 1560092400,
#    'apparentTemperatureLow': 53.97,
#    'apparentTemperatureLowTime': 1560164400,
#    'dewPoint': 54.42,
#    'humidity': 0.68,
#    'pressure': 1016.27,
#    'windSpeed': 3.98,
#    'windGust': 27.47,
#    'windGustTime': 1560110400,
#    'windBearing': 313,
#    'cloudCover': 0.57,
#    'uvIndex': 6,
#    'uvIndexTime': 1560099600,
#    'visibility': 10,
#    'ozone': 317.2,
#    'temperatureMin': 61.01,
#    'temperatureMinTime': 1560139200,
#    'temperatureMax': 70.33,
#    'temperatureMaxTime': 1560056400,
#    'apparentTemperatureMin': 61.01,
#    'apparentTemperatureMinTime': 1560139200,
#    'apparentTemperatureMax': 70.33,
#    'apparentTemperatureMaxTime': 1560056400},
#   {'time': 1560142800,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.001,
#    'precipIntensityMaxTime': 1560200400,
#    'precipProbability': 0.06,
#    'precipType': 'rain',
#    'temperatureHigh': 73.32,
#    'temperatureHighTime': 1560200400,
#    'temperatureLow': 56.87,
#    'temperatureLowTime': 1560250800,
#    'apparentTemperatureHigh': 73.32,
#    'apparentTemperatureHighTime': 1560200400,
#    'apparentTemperatureLow': 56.87,
#    'apparentTemperatureLowTime': 1560250800,
#    'dewPoint': 45.17,
#    'humidity': 0.5,
#    'pressure': 1021.7,
#    'windSpeed': 8.18,
#    'windGust': 22.09,
#    'windGustTime': 1560146400,
#    'windBearing': 305,
#    'cloudCover': 0.09,
#    'uvIndex': 7,
#    'uvIndexTime': 1560186000,
#    'visibility': 10,
#    'ozone': 374.38,
#    'temperatureMin': 53.97,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 73.32,
#    'temperatureMaxTime': 1560200400,
#    'apparentTemperatureMin': 53.97,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 73.32,
#    'apparentTemperatureMaxTime': 1560200400},
#   {'time': 1560229200,
#    'summary': 'Light rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0365,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.79,
#    'precipType': 'rain',
#    'temperatureHigh': 74.29,
#    'temperatureHighTime': 1560279600,
#    'temperatureLow': 55.9,
#    'temperatureLowTime': 1560344400,
#    'apparentTemperatureHigh': 74.29,
#    'apparentTemperatureHighTime': 1560279600,
#    'apparentTemperatureLow': 55.9,
#    'apparentTemperatureLowTime': 1560344400,
#    'dewPoint': 47.43,
#    'humidity': 0.52,
#    'pressure': 1017.2,
#    'windSpeed': 8.1,
#    'windGust': 20.24,
#    'windGustTime': 1560312000,
#    'windBearing': 204,
#    'cloudCover': 0.53,
#    'uvIndex': 6,
#    'uvIndexTime': 1560272400,
#    'visibility': 9.71,
#    'ozone': 373.81,
#    'temperatureMin': 56.87,
#    'temperatureMinTime': 1560250800,
#    'temperatureMax': 74.29,
#    'temperatureMaxTime': 1560279600,
#    'apparentTemperatureMin': 56.87,
#    'apparentTemperatureMinTime': 1560250800,
#    'apparentTemperatureMax': 74.29,
#    'apparentTemperatureMaxTime': 1560279600},
#   {'time': 1560315600,
#    'summary': 'Rain in the morning and breezy until afternoon.',
#    'icon': 'rain',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0245,
#    'precipIntensityMax': 0.0782,
#    'precipIntensityMaxTime': 1560340800,
#    'precipProbability': 0.98,
#    'precipType': 'rain',
#    'temperatureHigh': 63.36,
#    'temperatureHighTime': 1560369600,
#    'temperatureLow': 49.22,
#    'temperatureLowTime': 1560423600,
#    'apparentTemperatureHigh': 63.36,
#    'apparentTemperatureHighTime': 1560369600,
#    'apparentTemperatureLow': 45.98,
#    'apparentTemperatureLowTime': 1560423600,
#    'dewPoint': 49.46,
#    'humidity': 0.72,
#    'pressure': 1010.8,
#    'windSpeed': 7.96,
#    'windGust': 32.84,
#    'windGustTime': 1560355200,
#    'windBearing': 26,
#    'cloudCover': 0.82,
#    'uvIndex': 4,
#    'uvIndexTime': 1560366000,
#    'visibility': 8.07,
#    'ozone': 387.97,
#    'temperatureMin': 54.65,
#    'temperatureMinTime': 1560351600,
#    'temperatureMax': 63.36,
#    'temperatureMaxTime': 1560369600,
#    'apparentTemperatureMin': 54.65,
#    'apparentTemperatureMinTime': 1560351600,
#    'apparentTemperatureMax': 63.36,
#    'apparentTemperatureMaxTime': 1560369600},
#   {'time': 1560402000,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0099,
#    'precipIntensityMax': 0.0302,
#    'precipIntensityMaxTime': 1560470400,
#    'precipProbability': 0.83,
#    'precipType': 'rain',
#    'temperatureHigh': 68.74,
#    'temperatureHighTime': 1560459600,
#    'temperatureLow': 54.46,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 68.74,
#    'apparentTemperatureHighTime': 1560459600,
#    'apparentTemperatureLow': 54.46,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 46.18,
#    'humidity': 0.62,
#    'pressure': 1010.5,
#    'windSpeed': 6.7,
#    'windGust': 27.89,
#    'windGustTime': 1560463200,
#    'windBearing': 310,
#    'cloudCover': 0.6,
#    'uvIndex': 4,
#    'uvIndexTime': 1560441600,
#    'visibility': 8.42,
#    'ozone': 386.05,
#    'temperatureMin': 49.22,
#    'temperatureMinTime': 1560423600,
#    'temperatureMax': 68.74,
#    'temperatureMaxTime': 1560459600,
#    'apparentTemperatureMin': 45.98,
#    'apparentTemperatureMinTime': 1560423600,
#    'apparentTemperatureMax': 68.74,
#    'apparentTemperatureMaxTime': 1560459600},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0073,
#    'precipIntensityMax': 0.0176,
#    'precipIntensityMaxTime': 1560556800,
#    'precipProbability': 0.29,
#    'precipType': 'rain',
#    'temperatureHigh': 73.33,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 55.84,
#    'temperatureLowTime': 1560592800,
#    'apparentTemperatureHigh': 73.33,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 55.84,
#    'apparentTemperatureLowTime': 1560592800,
#    'dewPoint': 49.96,
#    'humidity': 0.63,
#    'pressure': 1009.36,
#    'windSpeed': 6.92,
#    'windGust': 16.02,
#    'windGustTime': 1560528000,
#    'windBearing': 275,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560535200,
#    'visibility': 9.97,
#    'ozone': 357.21,
#    'temperatureMin': 54.46,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 73.33,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 54.46,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 73.33,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0066,
#    'precipIntensityMax': 0.0401,
#    'precipIntensityMaxTime': 1560643200,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 75.9,
#    'temperatureHighTime': 1560625200,
#    'temperatureLow': 59.41,
#    'temperatureLowTime': 1560679200,
#    'apparentTemperatureHigh': 75.9,
#    'apparentTemperatureHighTime': 1560625200,
#    'apparentTemperatureLow': 59.41,
#    'apparentTemperatureLowTime': 1560679200,
#    'dewPoint': 55.05,
#    'humidity': 0.69,
#    'pressure': 1012.18,
#    'windSpeed': 2.6,
#    'windGust': 9.47,
#    'windGustTime': 1560650400,
#    'windBearing': 313,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560618000,
#    'visibility': 10,
#    'ozone': 348.12,
#    'temperatureMin': 55.84,
#    'temperatureMinTime': 1560592800,
#    'temperatureMax': 75.9,
#    'temperatureMaxTime': 1560625200,
#    'apparentTemperatureMin': 55.84,
#    'apparentTemperatureMinTime': 1560592800,
#    'apparentTemperatureMax': 75.9,
#    'apparentTemperatureMaxTime': 1560625200}]}

# %%
daily_stuff =[daily_forecast['data'] for daily in daily_forecast ]

# %%
daily_stuff
# Out:
# [[{'time': 1559970000,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1559989660,
#    'sunsetTime': 1560045488,
#    'moonPhase': 0.19,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.002,
#    'precipIntensityMaxTime': 1560038400,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperatureHigh': 85.8,
#    'temperatureHighTime': 1560031200,
#    'temperatureLow': 63.76,
#    'temperatureLowTime': 1560078000,
#    'apparentTemperatureHigh': 85.8,
#    'apparentTemperatureHighTime': 1560031200,
#    'apparentTemperatureLow': 63.76,
#    'apparentTemperatureLowTime': 1560078000,
#    'dewPoint': 55.55,
#    'humidity': 0.49,
#    'pressure': 1013.25,
#    'windSpeed': 9.05,
#    'windGust': 20.89,
#    'windGustTime': 1560052800,
#    'windBearing': 153,
#    'cloudCover': 0,
#    'uvIndex': 9,
#    'uvIndexTime': 1560013200,
#    'visibility': 9.98,
#    'ozone': 313.04,
#    'temperatureMin': 67.95,
#    'temperatureMinTime': 1559991600,
#    'temperatureMax': 85.8,
#    'temperatureMaxTime': 1560031200,
#    'apparentTemperatureMin': 67.95,
#    'apparentTemperatureMinTime': 1559991600,
#    'apparentTemperatureMax': 85.8,
#    'apparentTemperatureMaxTime': 1560031200},
#   {'time': 1560056400,
#    'summary': 'Mostly cloudy throughout the day and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560076044,
#    'sunsetTime': 1560131927,
#    'moonPhase': 0.23,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0035,
#    'precipIntensityMaxTime': 1560106800,
#    'precipProbability': 0.2,
#    'precipType': 'rain',
#    'temperatureHigh': 69.57,
#    'temperatureHighTime': 1560092400,
#    'temperatureLow': 53.97,
#    'temperatureLowTime': 1560164400,
#    'apparentTemperatureHigh': 69.59,
#    'apparentTemperatureHighTime': 1560092400,
#    'apparentTemperatureLow': 53.97,
#    'apparentTemperatureLowTime': 1560164400,
#    'dewPoint': 54.42,
#    'humidity': 0.68,
#    'pressure': 1016.27,
#    'windSpeed': 3.98,
#    'windGust': 27.47,
#    'windGustTime': 1560110400,
#    'windBearing': 313,
#    'cloudCover': 0.57,
#    'uvIndex': 6,
#    'uvIndexTime': 1560099600,
#    'visibility': 10,
#    'ozone': 317.2,
#    'temperatureMin': 61.01,
#    'temperatureMinTime': 1560139200,
#    'temperatureMax': 70.33,
#    'temperatureMaxTime': 1560056400,
#    'apparentTemperatureMin': 61.01,
#    'apparentTemperatureMinTime': 1560139200,
#    'apparentTemperatureMax': 70.33,
#    'apparentTemperatureMaxTime': 1560056400},
#   {'time': 1560142800,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.001,
#    'precipIntensityMaxTime': 1560200400,
#    'precipProbability': 0.06,
#    'precipType': 'rain',
#    'temperatureHigh': 73.32,
#    'temperatureHighTime': 1560200400,
#    'temperatureLow': 56.87,
#    'temperatureLowTime': 1560250800,
#    'apparentTemperatureHigh': 73.32,
#    'apparentTemperatureHighTime': 1560200400,
#    'apparentTemperatureLow': 56.87,
#    'apparentTemperatureLowTime': 1560250800,
#    'dewPoint': 45.17,
#    'humidity': 0.5,
#    'pressure': 1021.7,
#    'windSpeed': 8.18,
#    'windGust': 22.09,
#    'windGustTime': 1560146400,
#    'windBearing': 305,
#    'cloudCover': 0.09,
#    'uvIndex': 7,
#    'uvIndexTime': 1560186000,
#    'visibility': 10,
#    'ozone': 374.38,
#    'temperatureMin': 53.97,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 73.32,
#    'temperatureMaxTime': 1560200400,
#    'apparentTemperatureMin': 53.97,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 73.32,
#    'apparentTemperatureMaxTime': 1560200400},
#   {'time': 1560229200,
#    'summary': 'Light rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0365,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.79,
#    'precipType': 'rain',
#    'temperatureHigh': 74.29,
#    'temperatureHighTime': 1560279600,
#    'temperatureLow': 55.9,
#    'temperatureLowTime': 1560344400,
#    'apparentTemperatureHigh': 74.29,
#    'apparentTemperatureHighTime': 1560279600,
#    'apparentTemperatureLow': 55.9,
#    'apparentTemperatureLowTime': 1560344400,
#    'dewPoint': 47.43,
#    'humidity': 0.52,
#    'pressure': 1017.2,
#    'windSpeed': 8.1,
#    'windGust': 20.24,
#    'windGustTime': 1560312000,
#    'windBearing': 204,
#    'cloudCover': 0.53,
#    'uvIndex': 6,
#    'uvIndexTime': 1560272400,
#    'visibility': 9.71,
#    'ozone': 373.81,
#    'temperatureMin': 56.87,
#    'temperatureMinTime': 1560250800,
#    'temperatureMax': 74.29,
#    'temperatureMaxTime': 1560279600,
#    'apparentTemperatureMin': 56.87,
#    'apparentTemperatureMinTime': 1560250800,
#    'apparentTemperatureMax': 74.29,
#    'apparentTemperatureMaxTime': 1560279600},
#   {'time': 1560315600,
#    'summary': 'Rain in the morning and breezy until afternoon.',
#    'icon': 'rain',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0245,
#    'precipIntensityMax': 0.0782,
#    'precipIntensityMaxTime': 1560340800,
#    'precipProbability': 0.98,
#    'precipType': 'rain',
#    'temperatureHigh': 63.36,
#    'temperatureHighTime': 1560369600,
#    'temperatureLow': 49.22,
#    'temperatureLowTime': 1560423600,
#    'apparentTemperatureHigh': 63.36,
#    'apparentTemperatureHighTime': 1560369600,
#    'apparentTemperatureLow': 45.98,
#    'apparentTemperatureLowTime': 1560423600,
#    'dewPoint': 49.46,
#    'humidity': 0.72,
#    'pressure': 1010.8,
#    'windSpeed': 7.96,
#    'windGust': 32.84,
#    'windGustTime': 1560355200,
#    'windBearing': 26,
#    'cloudCover': 0.82,
#    'uvIndex': 4,
#    'uvIndexTime': 1560366000,
#    'visibility': 8.07,
#    'ozone': 387.97,
#    'temperatureMin': 54.65,
#    'temperatureMinTime': 1560351600,
#    'temperatureMax': 63.36,
#    'temperatureMaxTime': 1560369600,
#    'apparentTemperatureMin': 54.65,
#    'apparentTemperatureMinTime': 1560351600,
#    'apparentTemperatureMax': 63.36,
#    'apparentTemperatureMaxTime': 1560369600},
#   {'time': 1560402000,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0099,
#    'precipIntensityMax': 0.0302,
#    'precipIntensityMaxTime': 1560470400,
#    'precipProbability': 0.83,
#    'precipType': 'rain',
#    'temperatureHigh': 68.74,
#    'temperatureHighTime': 1560459600,
#    'temperatureLow': 54.46,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 68.74,
#    'apparentTemperatureHighTime': 1560459600,
#    'apparentTemperatureLow': 54.46,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 46.18,
#    'humidity': 0.62,
#    'pressure': 1010.5,
#    'windSpeed': 6.7,
#    'windGust': 27.89,
#    'windGustTime': 1560463200,
#    'windBearing': 310,
#    'cloudCover': 0.6,
#    'uvIndex': 4,
#    'uvIndexTime': 1560441600,
#    'visibility': 8.42,
#    'ozone': 386.05,
#    'temperatureMin': 49.22,
#    'temperatureMinTime': 1560423600,
#    'temperatureMax': 68.74,
#    'temperatureMaxTime': 1560459600,
#    'apparentTemperatureMin': 45.98,
#    'apparentTemperatureMinTime': 1560423600,
#    'apparentTemperatureMax': 68.74,
#    'apparentTemperatureMaxTime': 1560459600},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0073,
#    'precipIntensityMax': 0.0176,
#    'precipIntensityMaxTime': 1560556800,
#    'precipProbability': 0.29,
#    'precipType': 'rain',
#    'temperatureHigh': 73.33,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 55.84,
#    'temperatureLowTime': 1560592800,
#    'apparentTemperatureHigh': 73.33,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 55.84,
#    'apparentTemperatureLowTime': 1560592800,
#    'dewPoint': 49.96,
#    'humidity': 0.63,
#    'pressure': 1009.36,
#    'windSpeed': 6.92,
#    'windGust': 16.02,
#    'windGustTime': 1560528000,
#    'windBearing': 275,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560535200,
#    'visibility': 9.97,
#    'ozone': 357.21,
#    'temperatureMin': 54.46,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 73.33,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 54.46,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 73.33,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0066,
#    'precipIntensityMax': 0.0401,
#    'precipIntensityMaxTime': 1560643200,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 75.9,
#    'temperatureHighTime': 1560625200,
#    'temperatureLow': 59.41,
#    'temperatureLowTime': 1560679200,
#    'apparentTemperatureHigh': 75.9,
#    'apparentTemperatureHighTime': 1560625200,
#    'apparentTemperatureLow': 59.41,
#    'apparentTemperatureLowTime': 1560679200,
#    'dewPoint': 55.05,
#    'humidity': 0.69,
#    'pressure': 1012.18,
#    'windSpeed': 2.6,
#    'windGust': 9.47,
#    'windGustTime': 1560650400,
#    'windBearing': 313,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560618000,
#    'visibility': 10,
#    'ozone': 348.12,
#    'temperatureMin': 55.84,
#    'temperatureMinTime': 1560592800,
#    'temperatureMax': 75.9,
#    'temperatureMaxTime': 1560625200,
#    'apparentTemperatureMin': 55.84,
#    'apparentTemperatureMinTime': 1560592800,
#    'apparentTemperatureMax': 75.9,
#    'apparentTemperatureMaxTime': 1560625200}],
#  [{'time': 1559970000,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1559989660,
#    'sunsetTime': 1560045488,
#    'moonPhase': 0.19,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.002,
#    'precipIntensityMaxTime': 1560038400,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperatureHigh': 85.8,
#    'temperatureHighTime': 1560031200,
#    'temperatureLow': 63.76,
#    'temperatureLowTime': 1560078000,
#    'apparentTemperatureHigh': 85.8,
#    'apparentTemperatureHighTime': 1560031200,
#    'apparentTemperatureLow': 63.76,
#    'apparentTemperatureLowTime': 1560078000,
#    'dewPoint': 55.55,
#    'humidity': 0.49,
#    'pressure': 1013.25,
#    'windSpeed': 9.05,
#    'windGust': 20.89,
#    'windGustTime': 1560052800,
#    'windBearing': 153,
#    'cloudCover': 0,
#    'uvIndex': 9,
#    'uvIndexTime': 1560013200,
#    'visibility': 9.98,
#    'ozone': 313.04,
#    'temperatureMin': 67.95,
#    'temperatureMinTime': 1559991600,
#    'temperatureMax': 85.8,
#    'temperatureMaxTime': 1560031200,
#    'apparentTemperatureMin': 67.95,
#    'apparentTemperatureMinTime': 1559991600,
#    'apparentTemperatureMax': 85.8,
#    'apparentTemperatureMaxTime': 1560031200},
#   {'time': 1560056400,
#    'summary': 'Mostly cloudy throughout the day and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560076044,
#    'sunsetTime': 1560131927,
#    'moonPhase': 0.23,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0035,
#    'precipIntensityMaxTime': 1560106800,
#    'precipProbability': 0.2,
#    'precipType': 'rain',
#    'temperatureHigh': 69.57,
#    'temperatureHighTime': 1560092400,
#    'temperatureLow': 53.97,
#    'temperatureLowTime': 1560164400,
#    'apparentTemperatureHigh': 69.59,
#    'apparentTemperatureHighTime': 1560092400,
#    'apparentTemperatureLow': 53.97,
#    'apparentTemperatureLowTime': 1560164400,
#    'dewPoint': 54.42,
#    'humidity': 0.68,
#    'pressure': 1016.27,
#    'windSpeed': 3.98,
#    'windGust': 27.47,
#    'windGustTime': 1560110400,
#    'windBearing': 313,
#    'cloudCover': 0.57,
#    'uvIndex': 6,
#    'uvIndexTime': 1560099600,
#    'visibility': 10,
#    'ozone': 317.2,
#    'temperatureMin': 61.01,
#    'temperatureMinTime': 1560139200,
#    'temperatureMax': 70.33,
#    'temperatureMaxTime': 1560056400,
#    'apparentTemperatureMin': 61.01,
#    'apparentTemperatureMinTime': 1560139200,
#    'apparentTemperatureMax': 70.33,
#    'apparentTemperatureMaxTime': 1560056400},
#   {'time': 1560142800,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.001,
#    'precipIntensityMaxTime': 1560200400,
#    'precipProbability': 0.06,
#    'precipType': 'rain',
#    'temperatureHigh': 73.32,
#    'temperatureHighTime': 1560200400,
#    'temperatureLow': 56.87,
#    'temperatureLowTime': 1560250800,
#    'apparentTemperatureHigh': 73.32,
#    'apparentTemperatureHighTime': 1560200400,
#    'apparentTemperatureLow': 56.87,
#    'apparentTemperatureLowTime': 1560250800,
#    'dewPoint': 45.17,
#    'humidity': 0.5,
#    'pressure': 1021.7,
#    'windSpeed': 8.18,
#    'windGust': 22.09,
#    'windGustTime': 1560146400,
#    'windBearing': 305,
#    'cloudCover': 0.09,
#    'uvIndex': 7,
#    'uvIndexTime': 1560186000,
#    'visibility': 10,
#    'ozone': 374.38,
#    'temperatureMin': 53.97,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 73.32,
#    'temperatureMaxTime': 1560200400,
#    'apparentTemperatureMin': 53.97,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 73.32,
#    'apparentTemperatureMaxTime': 1560200400},
#   {'time': 1560229200,
#    'summary': 'Light rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0365,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.79,
#    'precipType': 'rain',
#    'temperatureHigh': 74.29,
#    'temperatureHighTime': 1560279600,
#    'temperatureLow': 55.9,
#    'temperatureLowTime': 1560344400,
#    'apparentTemperatureHigh': 74.29,
#    'apparentTemperatureHighTime': 1560279600,
#    'apparentTemperatureLow': 55.9,
#    'apparentTemperatureLowTime': 1560344400,
#    'dewPoint': 47.43,
#    'humidity': 0.52,
#    'pressure': 1017.2,
#    'windSpeed': 8.1,
#    'windGust': 20.24,
#    'windGustTime': 1560312000,
#    'windBearing': 204,
#    'cloudCover': 0.53,
#    'uvIndex': 6,
#    'uvIndexTime': 1560272400,
#    'visibility': 9.71,
#    'ozone': 373.81,
#    'temperatureMin': 56.87,
#    'temperatureMinTime': 1560250800,
#    'temperatureMax': 74.29,
#    'temperatureMaxTime': 1560279600,
#    'apparentTemperatureMin': 56.87,
#    'apparentTemperatureMinTime': 1560250800,
#    'apparentTemperatureMax': 74.29,
#    'apparentTemperatureMaxTime': 1560279600},
#   {'time': 1560315600,
#    'summary': 'Rain in the morning and breezy until afternoon.',
#    'icon': 'rain',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0245,
#    'precipIntensityMax': 0.0782,
#    'precipIntensityMaxTime': 1560340800,
#    'precipProbability': 0.98,
#    'precipType': 'rain',
#    'temperatureHigh': 63.36,
#    'temperatureHighTime': 1560369600,
#    'temperatureLow': 49.22,
#    'temperatureLowTime': 1560423600,
#    'apparentTemperatureHigh': 63.36,
#    'apparentTemperatureHighTime': 1560369600,
#    'apparentTemperatureLow': 45.98,
#    'apparentTemperatureLowTime': 1560423600,
#    'dewPoint': 49.46,
#    'humidity': 0.72,
#    'pressure': 1010.8,
#    'windSpeed': 7.96,
#    'windGust': 32.84,
#    'windGustTime': 1560355200,
#    'windBearing': 26,
#    'cloudCover': 0.82,
#    'uvIndex': 4,
#    'uvIndexTime': 1560366000,
#    'visibility': 8.07,
#    'ozone': 387.97,
#    'temperatureMin': 54.65,
#    'temperatureMinTime': 1560351600,
#    'temperatureMax': 63.36,
#    'temperatureMaxTime': 1560369600,
#    'apparentTemperatureMin': 54.65,
#    'apparentTemperatureMinTime': 1560351600,
#    'apparentTemperatureMax': 63.36,
#    'apparentTemperatureMaxTime': 1560369600},
#   {'time': 1560402000,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0099,
#    'precipIntensityMax': 0.0302,
#    'precipIntensityMaxTime': 1560470400,
#    'precipProbability': 0.83,
#    'precipType': 'rain',
#    'temperatureHigh': 68.74,
#    'temperatureHighTime': 1560459600,
#    'temperatureLow': 54.46,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 68.74,
#    'apparentTemperatureHighTime': 1560459600,
#    'apparentTemperatureLow': 54.46,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 46.18,
#    'humidity': 0.62,
#    'pressure': 1010.5,
#    'windSpeed': 6.7,
#    'windGust': 27.89,
#    'windGustTime': 1560463200,
#    'windBearing': 310,
#    'cloudCover': 0.6,
#    'uvIndex': 4,
#    'uvIndexTime': 1560441600,
#    'visibility': 8.42,
#    'ozone': 386.05,
#    'temperatureMin': 49.22,
#    'temperatureMinTime': 1560423600,
#    'temperatureMax': 68.74,
#    'temperatureMaxTime': 1560459600,
#    'apparentTemperatureMin': 45.98,
#    'apparentTemperatureMinTime': 1560423600,
#    'apparentTemperatureMax': 68.74,
#    'apparentTemperatureMaxTime': 1560459600},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0073,
#    'precipIntensityMax': 0.0176,
#    'precipIntensityMaxTime': 1560556800,
#    'precipProbability': 0.29,
#    'precipType': 'rain',
#    'temperatureHigh': 73.33,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 55.84,
#    'temperatureLowTime': 1560592800,
#    'apparentTemperatureHigh': 73.33,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 55.84,
#    'apparentTemperatureLowTime': 1560592800,
#    'dewPoint': 49.96,
#    'humidity': 0.63,
#    'pressure': 1009.36,
#    'windSpeed': 6.92,
#    'windGust': 16.02,
#    'windGustTime': 1560528000,
#    'windBearing': 275,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560535200,
#    'visibility': 9.97,
#    'ozone': 357.21,
#    'temperatureMin': 54.46,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 73.33,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 54.46,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 73.33,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0066,
#    'precipIntensityMax': 0.0401,
#    'precipIntensityMaxTime': 1560643200,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 75.9,
#    'temperatureHighTime': 1560625200,
#    'temperatureLow': 59.41,
#    'temperatureLowTime': 1560679200,
#    'apparentTemperatureHigh': 75.9,
#    'apparentTemperatureHighTime': 1560625200,
#    'apparentTemperatureLow': 59.41,
#    'apparentTemperatureLowTime': 1560679200,
#    'dewPoint': 55.05,
#    'humidity': 0.69,
#    'pressure': 1012.18,
#    'windSpeed': 2.6,
#    'windGust': 9.47,
#    'windGustTime': 1560650400,
#    'windBearing': 313,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560618000,
#    'visibility': 10,
#    'ozone': 348.12,
#    'temperatureMin': 55.84,
#    'temperatureMinTime': 1560592800,
#    'temperatureMax': 75.9,
#    'temperatureMaxTime': 1560625200,
#    'apparentTemperatureMin': 55.84,
#    'apparentTemperatureMinTime': 1560592800,
#    'apparentTemperatureMax': 75.9,
#    'apparentTemperatureMaxTime': 1560625200}],
#  [{'time': 1559970000,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1559989660,
#    'sunsetTime': 1560045488,
#    'moonPhase': 0.19,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.002,
#    'precipIntensityMaxTime': 1560038400,
#    'precipProbability': 0.02,
#    'precipType': 'rain',
#    'temperatureHigh': 85.8,
#    'temperatureHighTime': 1560031200,
#    'temperatureLow': 63.76,
#    'temperatureLowTime': 1560078000,
#    'apparentTemperatureHigh': 85.8,
#    'apparentTemperatureHighTime': 1560031200,
#    'apparentTemperatureLow': 63.76,
#    'apparentTemperatureLowTime': 1560078000,
#    'dewPoint': 55.55,
#    'humidity': 0.49,
#    'pressure': 1013.25,
#    'windSpeed': 9.05,
#    'windGust': 20.89,
#    'windGustTime': 1560052800,
#    'windBearing': 153,
#    'cloudCover': 0,
#    'uvIndex': 9,
#    'uvIndexTime': 1560013200,
#    'visibility': 9.98,
#    'ozone': 313.04,
#    'temperatureMin': 67.95,
#    'temperatureMinTime': 1559991600,
#    'temperatureMax': 85.8,
#    'temperatureMaxTime': 1560031200,
#    'apparentTemperatureMin': 67.95,
#    'apparentTemperatureMinTime': 1559991600,
#    'apparentTemperatureMax': 85.8,
#    'apparentTemperatureMaxTime': 1560031200},
#   {'time': 1560056400,
#    'summary': 'Mostly cloudy throughout the day and breezy in the afternoon.',
#    'icon': 'wind',
#    'sunriseTime': 1560076044,
#    'sunsetTime': 1560131927,
#    'moonPhase': 0.23,
#    'precipIntensity': 0.0008,
#    'precipIntensityMax': 0.0035,
#    'precipIntensityMaxTime': 1560106800,
#    'precipProbability': 0.2,
#    'precipType': 'rain',
#    'temperatureHigh': 69.57,
#    'temperatureHighTime': 1560092400,
#    'temperatureLow': 53.97,
#    'temperatureLowTime': 1560164400,
#    'apparentTemperatureHigh': 69.59,
#    'apparentTemperatureHighTime': 1560092400,
#    'apparentTemperatureLow': 53.97,
#    'apparentTemperatureLowTime': 1560164400,
#    'dewPoint': 54.42,
#    'humidity': 0.68,
#    'pressure': 1016.27,
#    'windSpeed': 3.98,
#    'windGust': 27.47,
#    'windGustTime': 1560110400,
#    'windBearing': 313,
#    'cloudCover': 0.57,
#    'uvIndex': 6,
#    'uvIndexTime': 1560099600,
#    'visibility': 10,
#    'ozone': 317.2,
#    'temperatureMin': 61.01,
#    'temperatureMinTime': 1560139200,
#    'temperatureMax': 70.33,
#    'temperatureMaxTime': 1560056400,
#    'apparentTemperatureMin': 61.01,
#    'apparentTemperatureMinTime': 1560139200,
#    'apparentTemperatureMax': 70.33,
#    'apparentTemperatureMaxTime': 1560056400},
#   {'time': 1560142800,
#    'summary': 'Clear throughout the day.',
#    'icon': 'clear-day',
#    'sunriseTime': 1560162430,
#    'sunsetTime': 1560218363,
#    'moonPhase': 0.27,
#    'precipIntensity': 0.0002,
#    'precipIntensityMax': 0.001,
#    'precipIntensityMaxTime': 1560200400,
#    'precipProbability': 0.06,
#    'precipType': 'rain',
#    'temperatureHigh': 73.32,
#    'temperatureHighTime': 1560200400,
#    'temperatureLow': 56.87,
#    'temperatureLowTime': 1560250800,
#    'apparentTemperatureHigh': 73.32,
#    'apparentTemperatureHighTime': 1560200400,
#    'apparentTemperatureLow': 56.87,
#    'apparentTemperatureLowTime': 1560250800,
#    'dewPoint': 45.17,
#    'humidity': 0.5,
#    'pressure': 1021.7,
#    'windSpeed': 8.18,
#    'windGust': 22.09,
#    'windGustTime': 1560146400,
#    'windBearing': 305,
#    'cloudCover': 0.09,
#    'uvIndex': 7,
#    'uvIndexTime': 1560186000,
#    'visibility': 10,
#    'ozone': 374.38,
#    'temperatureMin': 53.97,
#    'temperatureMinTime': 1560164400,
#    'temperatureMax': 73.32,
#    'temperatureMaxTime': 1560200400,
#    'apparentTemperatureMin': 53.97,
#    'apparentTemperatureMinTime': 1560164400,
#    'apparentTemperatureMax': 73.32,
#    'apparentTemperatureMaxTime': 1560200400},
#   {'time': 1560229200,
#    'summary': 'Light rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560248819,
#    'sunsetTime': 1560304797,
#    'moonPhase': 0.31,
#    'precipIntensity': 0.0055,
#    'precipIntensityMax': 0.0365,
#    'precipIntensityMaxTime': 1560308400,
#    'precipProbability': 0.79,
#    'precipType': 'rain',
#    'temperatureHigh': 74.29,
#    'temperatureHighTime': 1560279600,
#    'temperatureLow': 55.9,
#    'temperatureLowTime': 1560344400,
#    'apparentTemperatureHigh': 74.29,
#    'apparentTemperatureHighTime': 1560279600,
#    'apparentTemperatureLow': 55.9,
#    'apparentTemperatureLowTime': 1560344400,
#    'dewPoint': 47.43,
#    'humidity': 0.52,
#    'pressure': 1017.2,
#    'windSpeed': 8.1,
#    'windGust': 20.24,
#    'windGustTime': 1560312000,
#    'windBearing': 204,
#    'cloudCover': 0.53,
#    'uvIndex': 6,
#    'uvIndexTime': 1560272400,
#    'visibility': 9.71,
#    'ozone': 373.81,
#    'temperatureMin': 56.87,
#    'temperatureMinTime': 1560250800,
#    'temperatureMax': 74.29,
#    'temperatureMaxTime': 1560279600,
#    'apparentTemperatureMin': 56.87,
#    'apparentTemperatureMinTime': 1560250800,
#    'apparentTemperatureMax': 74.29,
#    'apparentTemperatureMaxTime': 1560279600},
#   {'time': 1560315600,
#    'summary': 'Rain in the morning and breezy until afternoon.',
#    'icon': 'rain',
#    'sunriseTime': 1560335210,
#    'sunsetTime': 1560391230,
#    'moonPhase': 0.34,
#    'precipIntensity': 0.0245,
#    'precipIntensityMax': 0.0782,
#    'precipIntensityMaxTime': 1560340800,
#    'precipProbability': 0.98,
#    'precipType': 'rain',
#    'temperatureHigh': 63.36,
#    'temperatureHighTime': 1560369600,
#    'temperatureLow': 49.22,
#    'temperatureLowTime': 1560423600,
#    'apparentTemperatureHigh': 63.36,
#    'apparentTemperatureHighTime': 1560369600,
#    'apparentTemperatureLow': 45.98,
#    'apparentTemperatureLowTime': 1560423600,
#    'dewPoint': 49.46,
#    'humidity': 0.72,
#    'pressure': 1010.8,
#    'windSpeed': 7.96,
#    'windGust': 32.84,
#    'windGustTime': 1560355200,
#    'windBearing': 26,
#    'cloudCover': 0.82,
#    'uvIndex': 4,
#    'uvIndexTime': 1560366000,
#    'visibility': 8.07,
#    'ozone': 387.97,
#    'temperatureMin': 54.65,
#    'temperatureMinTime': 1560351600,
#    'temperatureMax': 63.36,
#    'temperatureMaxTime': 1560369600,
#    'apparentTemperatureMin': 54.65,
#    'apparentTemperatureMinTime': 1560351600,
#    'apparentTemperatureMax': 63.36,
#    'apparentTemperatureMaxTime': 1560369600},
#   {'time': 1560402000,
#    'summary': 'Mostly cloudy throughout the day.',
#    'icon': 'partly-cloudy-day',
#    'sunriseTime': 1560421603,
#    'sunsetTime': 1560477660,
#    'moonPhase': 0.38,
#    'precipIntensity': 0.0099,
#    'precipIntensityMax': 0.0302,
#    'precipIntensityMaxTime': 1560470400,
#    'precipProbability': 0.83,
#    'precipType': 'rain',
#    'temperatureHigh': 68.74,
#    'temperatureHighTime': 1560459600,
#    'temperatureLow': 54.46,
#    'temperatureLowTime': 1560510000,
#    'apparentTemperatureHigh': 68.74,
#    'apparentTemperatureHighTime': 1560459600,
#    'apparentTemperatureLow': 54.46,
#    'apparentTemperatureLowTime': 1560510000,
#    'dewPoint': 46.18,
#    'humidity': 0.62,
#    'pressure': 1010.5,
#    'windSpeed': 6.7,
#    'windGust': 27.89,
#    'windGustTime': 1560463200,
#    'windBearing': 310,
#    'cloudCover': 0.6,
#    'uvIndex': 4,
#    'uvIndexTime': 1560441600,
#    'visibility': 8.42,
#    'ozone': 386.05,
#    'temperatureMin': 49.22,
#    'temperatureMinTime': 1560423600,
#    'temperatureMax': 68.74,
#    'temperatureMaxTime': 1560459600,
#    'apparentTemperatureMin': 45.98,
#    'apparentTemperatureMinTime': 1560423600,
#    'apparentTemperatureMax': 68.74,
#    'apparentTemperatureMaxTime': 1560459600},
#   {'time': 1560488400,
#    'summary': 'Partly cloudy starting in the evening.',
#    'icon': 'partly-cloudy-night',
#    'sunriseTime': 1560507998,
#    'sunsetTime': 1560564088,
#    'moonPhase': 0.41,
#    'precipIntensity': 0.0073,
#    'precipIntensityMax': 0.0176,
#    'precipIntensityMaxTime': 1560556800,
#    'precipProbability': 0.29,
#    'precipType': 'rain',
#    'temperatureHigh': 73.33,
#    'temperatureHighTime': 1560546000,
#    'temperatureLow': 55.84,
#    'temperatureLowTime': 1560592800,
#    'apparentTemperatureHigh': 73.33,
#    'apparentTemperatureHighTime': 1560546000,
#    'apparentTemperatureLow': 55.84,
#    'apparentTemperatureLowTime': 1560592800,
#    'dewPoint': 49.96,
#    'humidity': 0.63,
#    'pressure': 1009.36,
#    'windSpeed': 6.92,
#    'windGust': 16.02,
#    'windGustTime': 1560528000,
#    'windBearing': 275,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560535200,
#    'visibility': 9.97,
#    'ozone': 357.21,
#    'temperatureMin': 54.46,
#    'temperatureMinTime': 1560510000,
#    'temperatureMax': 73.33,
#    'temperatureMaxTime': 1560546000,
#    'apparentTemperatureMin': 54.46,
#    'apparentTemperatureMinTime': 1560510000,
#    'apparentTemperatureMax': 73.33,
#    'apparentTemperatureMaxTime': 1560546000},
#   {'time': 1560574800,
#    'summary': 'Rain overnight.',
#    'icon': 'rain',
#    'sunriseTime': 1560594396,
#    'sunsetTime': 1560650515,
#    'moonPhase': 0.45,
#    'precipIntensity': 0.0066,
#    'precipIntensityMax': 0.0401,
#    'precipIntensityMaxTime': 1560643200,
#    'precipProbability': 0.15,
#    'precipType': 'rain',
#    'temperatureHigh': 75.9,
#    'temperatureHighTime': 1560625200,
#    'temperatureLow': 59.41,
#    'temperatureLowTime': 1560679200,
#    'apparentTemperatureHigh': 75.9,
#    'apparentTemperatureHighTime': 1560625200,
#    'apparentTemperatureLow': 59.41,
#    'apparentTemperatureLowTime': 1560679200,
#    'dewPoint': 55.05,
#    'humidity': 0.69,
#    'pressure': 1012.18,
#    'windSpeed': 2.6,
#    'windGust': 9.47,
#    'windGustTime': 1560650400,
#    'windBearing': 313,
#    'cloudCover': 0.32,
#    'uvIndex': 8,
#    'uvIndexTime': 1560618000,
#    'visibility': 10,
#    'ozone': 348.12,
#    'temperatureMin': 55.84,
#    'temperatureMinTime': 1560592800,
#    'temperatureMax': 75.9,
#    'temperatureMaxTime': 1560625200,
#    'apparentTemperatureMin': 55.84,
#    'apparentTemperatureMinTime': 1560592800,
#    'apparentTemperatureMax': 75.9,
#    'apparentTemperatureMaxTime': 1560625200}]]

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
for time in daily_stuff:
    for yikes in time:
        print(f"for {yikes['time']} the high temperature is {yikes['temperatureHigh']}")
        if yikes['temperatureHigh'] > 75:
            print("it's hot!")
        elif yikes['temperatureHigh'] > 60:
            print("it's warm!")
        else:
            print("it's cold!")
# Out:
# for 1559970000 the high temperature is 85.8
# it's hot!
# for 1560056400 the high temperature is 69.57
# it's warm!
# for 1560142800 the high temperature is 73.32
# it's warm!
# for 1560229200 the high temperature is 74.29
# it's warm!
# for 1560315600 the high temperature is 63.36
# it's warm!
# for 1560402000 the high temperature is 68.74
# it's warm!
# for 1560488400 the high temperature is 73.33
# it's warm!
# for 1560574800 the high temperature is 75.9
# it's hot!
# for 1559970000 the high temperature is 85.8
# it's hot!
# for 1560056400 the high temperature is 69.57
# it's warm!
# for 1560142800 the high temperature is 73.32
# it's warm!
# for 1560229200 the high temperature is 74.29
# it's warm!
# for 1560315600 the high temperature is 63.36
# it's warm!
# for 1560402000 the high temperature is 68.74
# it's warm!
# for 1560488400 the high temperature is 73.33
# it's warm!
# for 1560574800 the high temperature is 75.9
# it's hot!
# for 1559970000 the high temperature is 85.8
# it's hot!
# for 1560056400 the high temperature is 69.57
# it's warm!
# for 1560142800 the high temperature is 73.32
# it's warm!
# for 1560229200 the high temperature is 74.29
# it's warm!
# for 1560315600 the high temperature is 63.36
# it's warm!
# for 1560402000 the high temperature is 68.74
# it's warm!
# for 1560488400 the high temperature is 73.33
# it's warm!
# for 1560574800 the high temperature is 75.9
# it's hot!

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
hottest_day=0
hottest_temp=0
for time in daily_stuff:
    for yikes in time:
        if yikes['temperatureHigh'] > hottest_temp:
            hottest_temp = yikes['temperatureHigh']
            hottest_day = yikes['time']

# %%
hottest_day = datetime.utcfromtimestamp(int(hottest_day)).strftime('%Y-%m-%d %H:%M')

# %%
hottest_day
# Out:
# '2019-06-08 05:00'

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
#25.7617° N, 80.1918° W (miami)
url_miami =f'https://api.darksky.net/forecast/{API_KEY}/25.7617,-80.1918'

# %%
data_miami = requests.get(url_miami).json()

# %%
miami = data_miami['hourly']['data']

# %%
for hour in miami:
    print(f"for {hour['time']}, temperature is {hour['temperature']}")
    if hour['cloudCover'] > .50:
        print("and cloudy")
# Out:
# for 1560020400, temperature is 81.37
# and cloudy
# for 1560024000, temperature is 80.23
# and cloudy
# for 1560027600, temperature is 80.26
# and cloudy
# for 1560031200, temperature is 84.06
# and cloudy
# for 1560034800, temperature is 86.16
# and cloudy
# for 1560038400, temperature is 84.98
# and cloudy
# for 1560042000, temperature is 83.87
# and cloudy
# for 1560045600, temperature is 83.19
# and cloudy
# for 1560049200, temperature is 82.54
# and cloudy
# for 1560052800, temperature is 81.97
# for 1560056400, temperature is 81.58
# for 1560060000, temperature is 79.71
# for 1560063600, temperature is 78.2
# for 1560067200, temperature is 77.74
# for 1560070800, temperature is 77.92
# for 1560074400, temperature is 77.93
# for 1560078000, temperature is 78.71
# for 1560081600, temperature is 79.77
# for 1560085200, temperature is 82.03
# for 1560088800, temperature is 84.04
# for 1560092400, temperature is 85.6
# for 1560096000, temperature is 86.95
# for 1560099600, temperature is 89.44
# for 1560103200, temperature is 90.76
# for 1560106800, temperature is 90.35
# for 1560110400, temperature is 88.98
# and cloudy
# for 1560114000, temperature is 87.44
# and cloudy
# for 1560117600, temperature is 86.03
# and cloudy
# for 1560121200, temperature is 84.49
# and cloudy
# for 1560124800, temperature is 83.42
# and cloudy
# for 1560128400, temperature is 82.84
# and cloudy
# for 1560132000, temperature is 82.68
# and cloudy
# for 1560135600, temperature is 82.38
# and cloudy
# for 1560139200, temperature is 81.74
# and cloudy
# for 1560142800, temperature is 81.13
# and cloudy
# for 1560146400, temperature is 79
# and cloudy
# for 1560150000, temperature is 77.13
# and cloudy
# for 1560153600, temperature is 76.85
# and cloudy
# for 1560157200, temperature is 77.09
# and cloudy
# for 1560160800, temperature is 77.9
# and cloudy
# for 1560164400, temperature is 79.01
# and cloudy
# for 1560168000, temperature is 80.52
# and cloudy
# for 1560171600, temperature is 82.65
# and cloudy
# for 1560175200, temperature is 84.36
# and cloudy
# for 1560178800, temperature is 85.49
# and cloudy
# for 1560182400, temperature is 86.85
# and cloudy
# for 1560186000, temperature is 89.5
# and cloudy
# for 1560189600, temperature is 90.83
# and cloudy
# for 1560193200, temperature is 90.44
# and cloudy

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
above_85 =0
total_hours =len(miami)

# %%
for hour in miami:
    if hour['temperature'] > 85: 
        above_85+=1
print(f"{round(above_85/total_hours*100)}%")
# Out:
# 86%

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*
